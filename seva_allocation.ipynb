# %%
import argparse
import json
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, util
import numpy as np
import pandas as pd
import re
import ast

import os
# Out:
# /usr/local/lib/python3.9/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
vrf_data_path = "TOY_DATA/TOY_vrf_data2024.xlsx"
seva_data_path = "TOY_DATA/TOY_seva_modified20apr.xlsx"
linkedin_data_path = "TOY_DATA/TOY_linkedin_data.xlsx"
degree_to_skill_mapping_path = "TOY_DATA/degree_profession_mapping.json"
job_clusters_latest = "TOY_DATA/JOB_CLUSTERS_LATEST.txt"


vrf_data_df = pd.read_excel(vrf_data_path)
og_seva_df = pd.read_excel(seva_data_path)
linkedin_df = pd.read_excel(linkedin_data_path)

# Optional degree to skill mapping
degree_profession_mapping = {}
if degree_to_skill_mapping_path:
    with open(degree_to_skill_mapping_path, "r") as json_file: # "degree_profession_mapping.json"
        degree_profession_mapping = json.load(json_file)


# Function to read and convert JOB_CLUSTERS_LATEST from a text file
def read_job_clusters_latest(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    return content

# Reading and processing the JOB_CLUSTERS_LATEST file
JOB_CLUSTERS_LATEST = read_job_clusters_latest(job_clusters_latest)

# Combine and process data
master_sheet_df = og_seva_df.copy()
master_sheet_df['SKILLS_ALL'] = og_seva_df['Any Additional Skills'].fillna(' ') + ' ' + og_seva_df['Computer Skills'].fillna(' ') + ' ' + og_seva_df['Skills'].fillna(' ') + ' ' + og_seva_df['Skills.1'].fillna(' ')
master_sheet_df['WORK_EXPERIENCE_ALL'] = np.NaN
for work_col in ['Work Experience/Company', 'Work Experience/Designation', 'Work Experience/Tasks', 'Work Experience/Industry', 'Work Experience/From Date', 'Work Experience/To Date']:
    master_sheet_df['WORK_EXPERIENCE_ALL'] = master_sheet_df['WORK_EXPERIENCE_ALL'].fillna(' ') + ' ' + master_sheet_df[work_col].fillna(' ')
master_sheet_df['WORK_EXPERIENCE_ALL'] = master_sheet_df['WORK_EXPERIENCE_ALL'].apply(lambda s: s.strip())


master_sheet_df['HOBBIES_ALL'] = np.NaN
for hobbies_col in ['Any Hobbies/Interests', 'Hobbies/Interests/Type', 'Hobbies/Interests/Name']:
    master_sheet_df['HOBBIES_ALL'] = master_sheet_df['HOBBIES_ALL'].fillna(' ') + ' ' + master_sheet_df[hobbies_col].fillna(' ')

master_sheet_df['CONCERNS_ALL'] = master_sheet_df['Concerns'].fillna(' ') + ' ' + master_sheet_df['Please enter any concerns here'].fillna(' ')

master_sheet_df['LANGUAGES_ALL'] = np.NaN

for lang_col in ['Languages',
'Languages/Can read',
'Languages/Can speak',
'Languages/Can type',
'Languages/Can write']:
    master_sheet_df['LANGUAGES_ALL'] = master_sheet_df['LANGUAGES_ALL'].fillna(' ') + ' ' + master_sheet_df[lang_col].fillna(' ')

master_sheet_df['LANGUAGES_ALL'] = master_sheet_df['LANGUAGES_ALL'].apply(lambda s : s.strip())

master_sheet_df.rename(columns={"Concerns":"CONCERNS_ALL", "Gender":"GENDER_ALL", "Age":"AGE_ALL"}, inplace=True)


linkedin_df.rename(columns={'SP ID':'SP_ID'}, inplace=True)

linkedin_df = linkedin_df.add_suffix('_LINKEDIN')
master_sheet_df = master_sheet_df.add_suffix('_APPLICATIONFORM')

linkedin_df.rename(columns={'SP_ID_LINKEDIN':'SP_ID'}, inplace=True)
master_sheet_df.rename(columns={'SP ID_APPLICATIONFORM':'SP_ID'}, inplace=True)

# new_df = pd.read_excel('../data/skill_comparison_output_ALL_ROWS_phase2_v1.xlsx')


# List of unwanted skills
unwanted_skills = [
    'Basic Computer Skills / Basic Computer (MS Office and Email) Skills',
    'Soft Skills / Fit for Physical Seva',
    'Soft Skills / Soft-spoken and cordial',
    'Soft Skills / Enthusiastic',
    'Soft Skills / Articulate in communication'
]

# Split skills on '\n' and reset index to preserve 'SP_ID'
skills_df = og_seva_df[['SP ID', 'Skills']].assign(Skills=og_seva_df['Skills'].str.split('\n')).explode('Skills').reset_index(drop=True)

# Filter unwanted skills
filtered_skills = skills_df[~skills_df['Skills'].isin(unwanted_skills)].reset_index(drop=True)

# Concatenate remaining skills with comma
cleaned_skills = filtered_skills.groupby('SP ID')['Skills'].agg(', '.join).reset_index(name='Cleaned_Skills')

# Merge with master_sheet_df on 'SP_ID'
result_df = master_sheet_df.merge(cleaned_skills, left_on='SP_ID', right_on='SP ID', how='left')

result_df.drop(columns=['SP ID'], inplace=True)

master_sheet_df = result_df.rename(columns={'Cleaned_Skills':'INTERVIEWER_SKILLS'})

# %%
master_sheet_df
# Out:
#       SP_ID Registration Batch _APPLICATIONFORM GENDER_ALL_APPLICATIONFORM  \
# 0    577769                           2024-2025                       male
# 1    579349                           2024-2026                     female
# 2    576830                           2024-2027                       male
# 3    577412                           2024-2028                     female
# 4    577678                           2024-2029                       male
# ..      ...                                 ...                        ...
# 669  574736                           2024-2694                       male
# 670  574706                           2024-2695                       male
# 671  574685                           2024-2696                       male
# 672  574641                           2024-2697                       male
# 673  576455                           2024-2698                       male
#
#      AGE_ALL_APPLICATIONFORM  Seva Dept_APPLICATIONFORM City_APPLICATIONFORM  \
# 0                         34                        NaN            Bengaluru
# 1                         27                        NaN            Panchkula
# 2                         23                        NaN     Bellary District
# 3                         26                        NaN             Warangal
# 4                         35                        NaN           Aurangabad
# ..                       ...                        ...                  ...
# 669                       25                        NaN            Bengaluru
# 670                       27                        NaN            Bengaluru
# 671                       20                        NaN                Karad
# 672                       31                        NaN        Vasco Da Gama
# 673                       26                        NaN          Vasai Virar
#
#     State_APPLICATIONFORM Nationality_APPLICATIONFORM Country_APPLICATIONFORM  \
# 0               Karnataka                       India                   India
# 1                 Haryana                       India                   India
# 2               Karnataka                       India                   India
# 3               Telangana                       India                   India
# 4             Maharashtra                       India                   India
# ..                    ...                         ...                     ...
# 669             Karnataka                       India                   India
# 670             Karnataka                       India                   India
# 671           Maharashtra                       India                   India
# 672                   Goa                       India                   India
# 673           Maharashtra                       India                   India
#
#                Work Experience/Company_APPLICATIONFORM  ...  \
# 0                                     Ripplr Storeking  ...
# 1                                      Teleperformance  ...
# 2    Ashirwad Construction Company Ashirwad Constru...  ...
# 3    ICF International, Global Consultancy Services...  ...
# 4              CSMSS CHH. SHAHU COLLEGE OF ENGINEERING  ...
# ..                                                 ...  ...
# 669       Gostol TST Limited Ganesh Power Technologies  ...
# 670                                  upgrad phablecare  ...
# 671                                                NaN  ...
# 672                   Indusind Bank Ltd ICICI BANK LTD  ...
# 673                      IDFC bank Kotak Mahindra Bank  ...
#
#                  Any Hobbies/Interests_APPLICATIONFORM  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    She has her own insta channel, expressed her i...
# 4                                                  NaN
# ..                                                 ...
# 669                  compose kannada music and poetry.
# 670                                                NaN
# 671                        Trekking\nFootball\nCricket
# 672                                                NaN
# 673                                                NaN
#
#     Hobbies/Interests/Type_APPLICATIONFORM  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 669                          Communication
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Hobbies/Interests/Name_APPLICATIONFORM  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 669                                 Poetry
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#                      Isha Connect/Name_APPLICATIONFORM  \
# 0                          IE & some Isha volunteering
# 1                          IE & some Isha volunteering
# 2    IE & some Isha volunteering IE ++ Prospective FTV
# 3                                                IE ++
# 4                                                IE ++
# ..                                                 ...
# 669                        IE & some Isha volunteering
# 670                        IE & some Isha volunteering
# 671        Only IE IE & some Isha volunteering Fresher
# 672                       Only IE No Isha volunteering
# 673                                            Only IE
#
#                             SKILLS_ALL_APPLICATIONFORM  \
# 0      MS-word,Excel, powerpoint Soft Skills / Arti...
# 1      Na Soft Skills / Articulate in communication...
# 2    Has also learnt music production but not worke...
# 3    https://www.instagram.com/yogic.musings?utm_so...
# 4      data science, microsoft excel, artificial in...
# ..                                                 ...
# 669    I Have Basic Knowledge of Computer Soft Skil...
# 670  Tools - leadsquare, amio, salesforce (Sales To...
# 671    No Environment / Agriculture/ Farmer Basic C...
# 672    MS office Environment / Agriculture/ Farmer ...
# 673    Working in bank so have decent skill in comp...
#
#                    WORK_EXPERIENCE_ALL_APPLICATIONFORM  \
# 0    Ripplr Storeking Logistic Mananger Senior exec...
# 1    Teleperformance SME   BPO and KPO 2021-10-25 N...
# 2    Ashirwad Construction Company Ashirwad Constru...
# 3    ICF International, Global Consultancy Services...
# 4    CSMSS CHH. SHAHU COLLEGE OF ENGINEERING Assist...
# ..                                                 ...
# 669  Gostol TST Limited Ganesh Power Technologies S...
# 670  upgrad phablecare BDM Key account manager Reve...
# 671  NaT NaT NaT NaT NaT NaT NaT NaT NaT NaT NaT Na...
# 672  Indusind Bank Ltd ICICI BANK LTD Relationship ...
# 673  IDFC bank Kotak Mahindra Bank Relationship man...
#
#                            HOBBIES_ALL_APPLICATIONFORM  \
# 0
# 1
# 2
# 3      She has her own insta channel, expressed her...
# 4
# ..                                                 ...
# 669    compose kannada music and poetry. Communicat...
# 670
# 671                    Trekking\nFootball\nCricket
# 672
# 673
#
#                           CONCERNS_ALL_APPLICATIONFORM  \
# 0                                               none
# 1                                               none
# 2                                               none
# 3                                               none
# 4                                               none
# ..                                                 ...
# 669  minor smoking and alcohol stopped a year befor...
# 670                                             none
# 671                                             none
# 672  minor He used to smoke and drink for 7-8 years...
# 673                                             none
#
#                          LANGUAGES_ALL_APPLICATIONFORM  \
# 0    Kannada (R W S T) English (UK) (R W S T) Hindi...
# 1    English (US) (R W S T) Medium Medium Medium In...
# 2    Kannada (R W S ) English (US) (R W S T) Fluent...
# 3    Telugu / తెలుగు (R W S T) Hindi / हिंदी (R W S...
# 4    Marathi (R W S ) Hindi / हिंदी (R W S ) Englis...
# ..                                                 ...
# 669  Kannada (R W S ) English (UK) (R W S T) Hindi ...
# 670  English (US) (R W S T) Kannada (R W S T) Hindi...
# 671  Marathi (R W S T) English (UK) (R W S T) Fluen...
# 672   English (UK) (R W S T) Fluent Fluent Fast Fluent
# 673   English (US) (R W S T) Fluent Fluent Fast Fluent
#
#                                     INTERVIEWER_SKILLS
# 0    Soft Skills / Articulate in communication Basi...
# 1    Soft Skills / Articulate in communication Basi...
# 2    Soft Skills / Articulate in communication Basi...
# 3                    Engineering / Electrical Engineer
# 4                         Education / Teacher - Others
# ..                                                 ...
# 669  Soft Skills / Articulate in communication Basi...
# 670  Soft Skills / Articulate in communication Basi...
# 671  Environment / Agriculture/ Farmer Basic Comput...
# 672  Environment / Agriculture/ Farmer Soft Skills ...
# 673         Corporate / Financial & Accounting Manager
#
# [674 rows x 65 columns]

# %%
# Function to map degrees to professions
degrees_not_mapped = [ ]
def map_degrees_to_professions(degrees):
    skills_list = []
    for degree in degrees:
        if degree in degree_profession_mapping:
            skills_list.extend(degree_profession_mapping[degree])
        else:
            degrees_not_mapped.append('Degree Not Found: ' + degree)
    return ', '.join(skills_list)


# Apply the mapping function to create the 'EDUCATION_SKILLS' column
og_seva_df['EDUCATION_SKILLS'] = og_seva_df['Education/Qualifications'].apply(
    lambda x: map_degrees_to_professions(str(x).split('\n')) if not pd.isna(x) else ''
)


merged_df = pd.merge(master_sheet_df, og_seva_df[['SP ID', 'EDUCATION_SKILLS']], left_on='SP_ID', right_on='SP ID', how='inner')


master_sheet_df = merged_df.drop(columns='SP ID')


# ### Add DESIGNATION_SKILLS


# Step 0: Identify and handle duplicates and NaN values in 'Work Experience/Designation' column
og_seva_df['Work Experience/Designation'] = og_seva_df['Work Experience/Designation'].apply(lambda x: x.split('\n') if isinstance(x, str) else x)
og_seva_df_exploded = og_seva_df.explode('Work Experience/Designation')
og_seva_df_exploded.dropna(subset=['Work Experience/Designation'], inplace=True)
og_seva_df_exploded.drop_duplicates(subset=['SP ID', 'Work Experience/Designation'], inplace=True)

# Step 1: Group by 'SP_ID' and join the designations using commas
og_seva_df_grouped = og_seva_df_exploded.groupby('SP ID')['Work Experience/Designation'].agg(lambda x: ', '.join(str(v) for v in x)).reset_index()

# Check for duplicate 'SP_ID' values in og_seva_df_grouped
duplicates_og_seva = og_seva_df_grouped[og_seva_df_grouped.duplicated('SP ID')]
if not duplicates_og_seva.empty:
    raise ValueError(f'Duplicate SP_ID values found in og_seva_df_grouped: {duplicates_og_seva}')

# Step 2: Reset index in 'master_sheet_df' if needed
master_sheet_df_reset = master_sheet_df.reset_index()

# Check for duplicate 'SP_ID' values in master_sheet_df_reset
duplicates_master_sheet = master_sheet_df_reset[master_sheet_df_reset.duplicated('SP_ID')]
if not duplicates_master_sheet.empty:
    raise ValueError(f'Duplicate SP ID values found in master_sheet_df_reset: {duplicates_master_sheet}')

# Step 3: Merge with 'master_sheet_df_reset' on 'SP_ID'
merged_df = pd.merge(master_sheet_df_reset, og_seva_df_grouped, left_on='SP_ID', right_on='SP ID', how='left')

# Now 'merged_df' contains the desired result with designations separated by commas


merged_df.rename(columns={'Work Experience/Designation':'DESIGNATION_SKILLS'}, inplace=True)


merged_df.drop('SP ID', axis=1, inplace=True)


master_sheet_df = merged_df

# %%
## RE-RUNNING SKILL COMPARISON

df_vrf = vrf_data_df

df_vrf = df_vrf[['Department', '/']].rename(columns = {'/':'Job Title'})

# %%
def concatenate_skills(row):
    skills_list = []

    # INTERVIEWER_SKILLS
    if not pd.isna(row['INTERVIEWER_SKILLS']) and str(row['INTERVIEWER_SKILLS']).strip() != '':
        skills_list.append(str(row['INTERVIEWER_SKILLS']).strip(', '))

    # EDUCATION_SKILLS
    if not pd.isna(row['EDUCATION_SKILLS']) and str(row['EDUCATION_SKILLS']).strip() != '':
        skills_list.append(str(row['EDUCATION_SKILLS']).strip(', '))

    # DESIGNATION_SKILLS
    if not pd.isna(row['DESIGNATION_SKILLS']) and str(row['DESIGNATION_SKILLS']).strip() != '':
        skills_list.append(str(row['DESIGNATION_SKILLS']).strip(', '))

    # Combine non-empty skills using ', '
    combined_skills = ', '.join(skills_list)

    return combined_skills


# Apply the function to each row
master_sheet_df['COMBINED_SKILLS'] = master_sheet_df.apply(concatenate_skills, axis=1)

# Preprocess the data
VRF_job_titles = df_vrf['Job Title'].tolist()

# Preprocess the data
df_vrf_cleaned = df_vrf.dropna(subset=['Job Title'])
VRF_job_titles = df_vrf_cleaned['Job Title'].tolist()

# Replace NaN values with empty strings
updated_VRF_job_titles = ["" if pd.isna(title) else title for title in VRF_job_titles]
VRF_job_titles = updated_VRF_job_titles

# %%
VRF_job_titles
# Out:
# ['Arabic Translator',
#  'Translators',
#  'French Translator',
#  'Dining Support',
#  'Administrative Activities (Back Office)',
#  'Recruitment Officer',
#  'Site Supervisor',
#  'Coordinating Activities',
#  'German Translator',
#  'Translators',
#  'Translators',
#  'Indonesian Translator',
#  'Maintenance Support',
#  'Italian Translator',
#  'Japanese Translator',
#  'Korean Video Editor',
#  'Supervising Activities',
#  'Front Office Activities',
#  'Call Centre',
#  'Mandarin Chinese Translator',
#  'Persian Translator',
#  'Polish Translator',
#  'Portuguese Translator',
#  'Romanian Video Editor',
#  'Russian Video Editor',
#  'Accountant',
#  'Maintenance Support',
#  'Translators',
#  'Spanish Translator',
#  'Thai Translator',
#  'Guiding Visitors',
#  'Customer Support Representatives',
#  'Front Office Activities',
#  'Sales Manager/ Executive',
#  'Content Manager',
#  'Content Support Executive (CSE)',
#  'Content Writer',
#  'Social media Manager',
#  'Marketing Manager/ Executive',
#  'Administrative Activities (Back Office)',
#  'On ground Support',
#  'Content Writer',
#  'Media Operations',
#  'Guest Care Support',
#  'Video Editor',
#  'Graphic Designer',
#  'Content Researcher',
#  'Coordinating Activities',
#  'Recruitment Officer',
#  'Supervising Activities',
#  'Supervising Activities',
#  'CAD Designer',
#  'CAD Designer',
#  'Electrical Maintenance Support',
#  'Electrical Maintenance Support',
#  'Customer Support Representatives',
#  'Electrical Design Engineer',
#  'Electrical Engineer',
#  'Project Manager',
#  'Asset and Inventory management',
#  'Asset and Inventory management',
#  'Technical support for Audio',
#  'Coordinating Activities',
#  'Accountant',
#  'Accountant',
#  'Account Auditor',
#  'Accountant',
#  'Translators',
#  'Traditional Chinese Video Editor',
#  'Translators',
#  'Vietnamese Translator',
#  'Administrative Activities (Back Office)',
#  'Maintenance Activities',
#  'Class Teacher',
#  'Crafts Teacher',
#  'CAD Designer',
#  'Accountant',
#  'Finance & Accounting Executive',
#  'Chartered Accountant',
#  'Administrative Activities (Back Office)',
#  'Maintenance Support',
#  'On ground Support',
#  'Call Centre',
#  'Accountant',
#  'Administrative Activities (Back Office)',
#  'Session Facilitator',
#  'Safety Professionals',
#  'Veterinary Doctor',
#  'Tamil Translator',
#  'Farming support',
#  'Data Analyst',
#  'Product/ Mechanical Engineer',
#  'Farming support',
#  'Guest Care Support',
#  'Guest Care Support',
#  'Guest Care Support',
#  'Site Supervisor',
#  'Guest Care Support',
#  'Test Engineer',
#  'Carnatic Music Teacher',
#  'Singers / Instrumentalists / Musicians',
#  'English Teacher',
#  'Content Writer',
#  'Tamil Teacher',
#  'Media Coordinator',
#  'Video Editor',
#  'Graphic Designer',
#  'Communication/Soft skill Teacher',
#  'UX Desinger',
#  'Conversion Rate Expert',
#  'Administrative Activities (Back Office)',
#  'Administrative Activities (Back Office)',
#  'Coordinating Activities',
#  'Call Centre',
#  'Promotions',
#  'Customer Support Representatives',
#  'Creative Director',
#  'Accountant',
#  'On ground Support',
#  'Content Writer',
#  'Researcher',
#  'Artificial Intelligence (AI) Enthusiast',
#  'Hindi Translator',
#  'Business Analyst (BA)',
#  'Dubbing Artist',
#  'Kannada Translator',
#  'Telugu Translator',
#  'Bengali Translator',
#  'Malayalam Translator',
#  'Marathi Translator',
#  'Gujarati Translator',
#  'Assamese Translator',
#  'Odia Translator',
#  'Nepali Translator',
#  'Punjabi Translator',
#  'Customer Support Representatives',
#  'Social media Manager',
#  'Physiotherapist',
#  'Farming support',
#  'Allopathy Doctor',
#  'Nurse',
#  'Pharmacist',
#  'Administrative Activities (Back Office)',
#  'Farming support',
#  'Front Office Activities',
#  'TN',
#  'Researcher',
#  'Data Analyst',
#  'Call Centre',
#  'Allopathy Doctor',
#  'Dentist',
#  'On ground Support',
#  'Content Writer',
#  'Guest Care Support',
#  'LSP',
#  'LSP',
#  'LSP',
#  'LSP',
#  'Transcription',
#  'LSP',
#  'LSP',
#  'LSP',
#  'LSP',
#  'LSP',
#  'LSP',
#  'Data Analyst',
#  'Project Manager',
#  'Google Tag Manager / Google Analytics Specialist',
#  'Data Analyst',
#  'Data Scientist',
#  'Business Analyst (BA)',
#  'Paid Ads Expert',
#  'Social media Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Maths Teacher',
#  'Platform Manager',
#  'Platform Manager',
#  'Social media Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'On ground Support',
#  'Platform Manager',
#  'Platform Manager',
#  'Agri Marketing',
#  'Finance & Accounting Executive',
#  'Crop Husbandry',
#  'Coordinating Activities',
#  'Data Analyst',
#  'Content Creator',
#  'Video Editor',
#  'Social media Manager',
#  'Data Analyst',
#  'Researcher',
#  'Chartered Accountant',
#  'Finance & Accounting Executive',
#  'Data Analyst',
#  'Company Secretary',
#  'Content Creator',
#  'Copywriter & Script Writer',
#  'Graphic Designer',
#  'Account Auditor',
#  'Project Manager',
#  'LSP',
#  'LSP',
#  'Front Office Activities',
#  'Access Control',
#  'Access Control',
#  'Marketing Manager/ Executive',
#  'On ground Support',
#  'Developer',
#  'Promotions',
#  'Front Office Activities',
#  'On ground Support',
#  'Platform Manager',
#  'Social media Manager',
#  'Platform Manager',
#  'Content Strategist',
#  'Content Strategist',
#  'Media Coordinator',
#  'Media Operations',
#  'Data Analyst',
#  'Project Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Graphic Designer',
#  'Video Editor',
#  'Content Strategist',
#  'Content Creator',
#  'Content Researcher',
#  'Copywriter & Script Writer',
#  'Content Writer',
#  'Project Manager',
#  'Copywriter & Script Writer',
#  'Content Writer',
#  'Growth Marketing Manager',
#  'Marketing Manager/ Executive',
#  'Content Writer',
#  'Ad Creative Design Expert',
#  'Market Research',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Platform Manager',
#  'Electrical Design Engineer',
#  'Coordinating Activities',
#  'English Teacher',
#  'Class Teacher',
#  'Art Teacher',
#  'Content Researcher',
#  'Coordinating Activities',
#  'Social media Manager',
#  'Social media Manager',
#  'Social media Manager',
#  'Content Creator',
#  'Project Manager',
#  'UI Designer',
#  'Content Writer',
#  'Business Analyst (BA)',
#  'Content Strategist',
#  'Product Development',
#  'Customer Support Representatives',
#  'Marketing Manager/ Executive',
#  'Growth Marketing Manager',
#  'Finance & Accounting Executive',
#  'Accountant',
#  'Finance & Accounting Executive',
#  'Finance & Accounting Executive',
#  'Accountant']

# %%
master_sheet_df['COMBINED_SKILLS'].iloc[22]
# Out:
# 'Basic Computer Skills / Basic Computer (MS Office and Email) Skills Others / Cab Driver General / Retail, Accountant, Financial Analyst, Driver Assistant branch manager'

# %%
model = SentenceTransformer('sentence-transformers/all-roberta-large-v1', device='cpu')

print('EMBEDDING SKILLS...')

job_title_corr_mat = np.zeros((len(master_sheet_df), len(VRF_job_titles)))
embeddings_master = model.encode(master_sheet_df['COMBINED_SKILLS'], convert_to_tensor=True, show_progress_bar=True, device='cpu')

print('EMBEDDING JOB TITLES...')


embeddings_vrf = model.encode(VRF_job_titles, convert_to_tensor=True, show_progress_bar=True, device='cpu')

print('COMPUTING COSINE SIMILARITY SCORES...')

# # Compute cosine similarity scores
cosine_scores = util.cos_sim(embeddings_master, embeddings_vrf)

# Create a list to store the results

print('SCORING AND MATCHING SKILLS TO JOB TITLES...')

results = []

# Iterate through SP_IDs and df_vrf rows to calculate skill scores
for i, sp_id in enumerate(master_sheet_df['SP_ID']):
    for (j, row) in df_vrf.dropna(subset=['Job Title']).reset_index(drop=True).iterrows():
        department = row['Department']
        job_title = row['Job Title']

        # Ensure that the indices are within bounds
        if i < len(cosine_scores) and j < len(cosine_scores[i]):
            # Extract skills for the SP_ID (as per your previous code)
            participant_skills = master_sheet_df[master_sheet_df['SP_ID'] == sp_id]['COMBINED_SKILLS'].iloc[0]

            # Calculate the skill score
            raw_skill_score = cosine_scores[i, j]
            skill_score = 0 if pd.isna(raw_skill_score) else raw_skill_score

            # Store the results including SP_ID, row number, department, job title, and skill score
            results.append({
                'SP_ID': sp_id,
                'Row Number': j,
                'Department': department,
                'Job Title': job_title,
                'Skill Score': skill_score
            })
        else:
            print(f"Warning: Index out of bounds - i={i}, j={j}")

# Convert the results to a DataFrame
results_df = pd.DataFrame(results)

results_df['Skill Score'] = results_df['Skill Score'].apply(lambda x: x.numpy())

results_df_department_not_null = results_df[~results_df['Department'].isna()]

results_df_department_not_null = results_df_department_not_null.groupby(['SP_ID', 'Department', 'Job Title', 'Skill Score']).size().reset_index(name="Count")

results_df_department_not_null.drop(columns=['Count'], inplace=True)

# Grouping by 'SP_ID' and sorting each group by 'Skill Score' in descending order
results_df_department_not_null = results_df_department_not_null.groupby('SP_ID', group_keys=False).apply(lambda group: group.sort_values('Skill Score', ascending=False))

# Resetting the index after sorting
results_df_department_not_null.reset_index(drop=True, inplace=True)

def invert_job_clusters(job_clusters):
    optimized_dict = {}
    for main_category, subcategories in job_clusters.items():
        for subcategory, titles in subcategories.items():
            for title in titles:
                optimized_dict[title] = (main_category, subcategory)
    return optimized_dict

def get_category_optimized(job_title, optimized_dict):
    return optimized_dict.get(job_title, ("Not Found", "Not Found"))

# Function to convert a pretty-printed tree to a regular dictionary
def pretty_tree_to_regular(pretty_str):
    tree = {}
    lines = pretty_str.strip().split('\n')

    # Regular expressions to identify levels based on indentation
    pattern = re.compile(r'^( *)(- )?(.*)')

    # Helper function to insert an item into the tree based on indentation levels
    def insert_into_tree(tree, levels, item):
        for level in levels[:-1]:
            tree = tree.setdefault(level, {})
        tree.setdefault(levels[-1], []).append(item)

    # Stack to keep track of the current hierarchy based on indentation
    hierarchy_stack = []
    for line in lines:
        indent, _, item = pattern.match(line).groups()
        level = len(indent) // 2  # Assuming two spaces per indent level

        # Adjust the current item by removing colon if we're at the first or second level
        if level <= 1 and item.endswith(':'):
            item = item[:-1]

        # If we're at a deeper level, just append to the stack
        if level > len(hierarchy_stack):
            hierarchy_stack.append(item)
        else:
            # If we're at a shallower level, reset the stack to that level
            hierarchy_stack = hierarchy_stack[:level]
            hierarchy_stack.append(item)

        # If it's a job title (prefixed with '- '), insert it into the tree
        if _:
            insert_into_tree(tree, hierarchy_stack[:-1], hierarchy_stack[-1])
            hierarchy_stack.pop()  # Remove the job title from the hierarchy stack

    return tree

# # Example usage:
# pretty_str = """
# Creative and Media:
#   Music and Audio:
#     - Music Producer / Arranger
#     - Mixing Engineer
#   Content Creation and Writing:
#     - Content Writer
# Information Technology and Software:
#   Development and Programming:
#     - Software Developer
# """

TREE_FORMAT_JOB_CLUSTERS_LATEST = pretty_tree_to_regular(JOB_CLUSTERS_LATEST)
OG_FORMAT_JOB_CLUSTERS_LATEST = invert_job_clusters(TREE_FORMAT_JOB_CLUSTERS_LATEST)

results_df_department_not_null['Predicted Cluster'] = results_df_department_not_null['Job Title'].apply(lambda x: ' - '.join(OG_FORMAT_JOB_CLUSTERS_LATEST.get(x, ("Not Found", "Not Found"))))

SKILLS_COLS = ['SP_ID', 'INTERVIEWER_SKILLS', 'EDUCATION_SKILLS', 'COMBINED_SKILLS']

SUMMARY_COLS = ['SP ID',
    'Education/Qualifications','Education/Institution\'s Name', 'Education/City', 'Education/Specialization', 'Education/Year of Passing/Graduation', 
    'Work Experience/Designation', 'Work Experience/Tasks', 'Work Experience/Industry', 'Work Experience/From Date', 'Work Experience/To Date',
    'Interviewer Feedback/Answer']

SUMMARY_TABLE = og_seva_df[SUMMARY_COLS]

predictions_data_path = "./TOY_DATA/predictions_data.xlsx"
extracted_skills_data_path = "./TOY_DATA/extracted_skills_data.xlsx"
summary_data_path = "./TOY_DATA/summary_data.xlsx"

# Save output data
# (Save your processed data frames to files as specified in the function arguments)
# Example:
print('SAVING OUTPUT...')
results_df_department_not_null.to_excel(predictions_data_path)
master_sheet_df[SKILLS_COLS].to_excel(extracted_skills_data_path)
SUMMARY_TABLE.to_excel(summary_data_path)
# Out:
# /usr/local/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# EMBEDDING SKILLS...
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]
# EMBEDDING JOB TITLES...
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# COMPUTING COSINE SIMILARITY SCORES...
# SCORING AND MATCHING SKILLS TO JOB TITLES...
# /var/folders/j6/588zcvgj0sdc9tfsz36sdcp40000gn/T/ipykernel_34936/2501586897.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   results_df_department_not_null = results_df_department_not_null.groupby('SP_ID', group_keys=False).apply(lambda group: group.sort_values('Skill Score', ascending=False))
# SAVING OUTPUT...

# %%
TREE_FORMAT_JOB_CLUSTERS_LATEST
# Out:
# {'\ufeffCreative and Media': {'Music and Audio': ['Music Producer / Arranger',
#    'Mixing Engineer',
#    'Singers / Instrumentalists / Musicians',
#    'Musician ( Singer and Drummer )',
#    'Music/Mridhamgam/violin/Tabla/Dance',
#    'Carnatic Music Teacher',
#    'Mridangam Teacher',
#    'Piano teacher',
#    'Tabla teacher',
#    'Dubbing artists',
#    'German Dubbing Artist',
#    'Russian Dubbing Artist',
#    'Mandarin Chinese Dubbing Artist',
#    'Japanese Dubbing Artist',
#    'Arabic Dubbing Artist',
#    'Vietnamese Dubbing Artist',
#    'Persian Dubbing Artist',
#    'Thai Dubbing Artist',
#    'Portuguese dubbing artist',
#    'Dubbing Artist',
#    'MSR - Audio, Cottage',
#    'Male Dubbing Voice'],
#   'Visual Arts': ['Photographer',
#    'Photo Editor / Photographer',
#    'Artist/ Illustrator',
#    'Artificial Intelligence (AI) Art Enthusiast',
#    'Art Teacher',
#    'Aesthetic/Artist/Illustrator',
#    'Product/Furniturer/Interior Designer',
#    'Crafts/origami teacher',
#    'Crafts Teacher',
#    'Teach fashion designing',
#    'Fashion Designer',
#    'Jewellery Designer'],
#   'Content Creation and Writing': ['Content Writer',
#    'Creative Content Writer (Tamil/ English)',
#    'Content writer - Media',
#    'Copywriter & Script Writer',
#    'Copywriter + script-writer',
#    'Content Creator',
#    'Content manager',
#    'Content Strategist',
#    'Content Researcher',
#    'Content Support Executive (CSE)',
#    'Sahaya - Content writer',
#    'Content & Communications',
#    'Content writer',
#    'Content Researcher for Tamil SM',
#    'Content Manager',
#    'Romanian Proofreader',
#    'Subtitling Support',
#    'Tamil content support',
#    'Offerings - Promotions - Content Creator',
#    'IE - Content Writer - IE Core Team',
#    'Website Blog Content Clean Up'],
#   'Video and Photography': ['Video Editor',
#    'Camera Man',
#    'Photo And Video Grapher',
#    'Video And Photo Editing',
#    'Video editor',
#    'Photo Tagging',
#    'Portuguese vide editor',
#    'German Video Editor',
#    'Russian Video Editor',
#    'Italian Video Editor',
#    'Polish Video Editor',
#    'French Video Editor',
#    'Mandarin Chinese Video Editor',
#    'Hebrew Video Editor',
#    'Japanese Video Editor',
#    'Vietnamese Video Editor',
#    'Persian Video Editor',
#    'Thai Video Editor',
#    'Indonesian Video Editor',
#    'Video Editor / Graphic Designer',
#    'Editors with Animation skills',
#    'Webinars program live streaming',
#    'video editor',
#    'Romanian Video Editor',
#    'Arabic Video Editor',
#    'Archives Support/Photography/Videography',
#    'IE - Video Editor',
#    'Archives Support/Photography/Videgraphy',
#    'Graphic Designer'],
#   'Graphic Design': ['Ad Creative Design Expert',
#    'Illustrations coordinator',
#    'designer'],
#   'Arts and Crafts': ['Mala Making (Garlands)', 'Carpentry'],
#   'Language Translation': ['Translators'],
#   'Creative Direction': ['Creative Director'],
#   'Editing and Publishing': ['Editor'],
#   'Production and Design': ['Temple Production']},
#  'Information Technology and Software': {'UI/UX and Graphic Design': ['Graphic Design',
#    'UI Designer',
#    'Designer',
#    'Graphic Designer (package)',
#    'Illustrator',
#    'Illustrator/video editor',
#    'UI/UX designer',
#    'Visual Merchandiser'],
#   'Technical Support and IT Services': ['Technical Content Writer',
#    'Technical support Person',
#    'ERP Support',
#    'Technical support for Sports',
#    'Tech support',
#    'Tech - Market Research',
#    'Technical Backend Support Assistant - IE Core Team',
#    'CTV gaps',
#    'IE - Technical Backend Support Assistant - IE Core Team'],
#   'Development and Programming': ['Software Developer',
#    'Mobile app developer',
#    'Developer',
#    'Cloud Architect',
#    'Automation & AI Python Developer',
#    'Web Developer',
#    'Project Management Tool developer (IT)',
#    'Mobile Health Clinic',
#    'IT Hardware engineer',
#    'Devops Engineer',
#    'Live Streaming Engineer'],
#   'Cybersecurity': ['Cyber Security Analyst', 'Cyber Security Engineer'],
#   'SEO and Digital Marketing': ['Technical SEO',
#    'Google Tag Manager / Google Analytics Specialist',
#    'SM Analytics',
#    'YT SEO',
#    'Live Streaming Support & Digital Marketing support.'],
#   'Network and Systems': ['Network Engineer',
#    'Server Engineer',
#    'End user computing / Desktop Support Engineer',
#    'IT Support'],
#   'Data Science and Analytics': ['Data Scientist',
#    'Data Analyst',
#    'Data and research analyst',
#    'Tech - Data Analytics',
#    'IE - Data Analyst - IE Core Team',
#    'Artificial Intelligence (AI) Enthusiast'],
#   'UI/UX Design': ['UX Designer', 'UX Desinger'],
#   'Business Analysis and Strategy': ['Business Analyst (BA)',
#    'Business analyst',
#    'Business Analyst',
#    'Business strategist'],
#   'Platform Management': ['Platform Managers',
#    'Platform Manager for Tamil SM',
#    'Platform Manager'],
#   'IT Management': ['Sadhguru Sahabhagi and IT', 'Offerings - IT'],
#   'Customer and Technical Support': ['Applications - Audio calls',
#    'Applications - Video calls'],
#   'Social Media Management': ['Whatsapp coordinator'],
#   'Quality Assurance and Testing': ['Business Analyst and Software Tester',
#    'Test Engineer'],
#   'Web Development and Management': ['Website building and management'],
#   'Software Development': ['Form Building'],
#   'Management Information Systems': ['Report -MIS']},
#  'Education and Training': {'Language and Translation': ['Spanish Video Editor',
#    'Traditional Chinese Video Editor',
#    'Korean Video Editor',
#    'Translator',
#    'Nepali Translator',
#    'Punjabi Translator',
#    'Odia Translator',
#    'Gujarati Translator',
#    'Malayalam Translator',
#    'Marathi Translator',
#    'Hindi Translator',
#    'Portuguese Translator',
#    'Telugu Translator',
#    'Gujarati publication associate',
#    'Odia Publication Associate',
#    'Nepali Publication Associate',
#    'Kannada Publication associate',
#    'Hindi Publication associate',
#    'Marathi Publication Associate',
#    'Telugu Publication Associate',
#    'Bengali Publication associate',
#    'Malayalam publication associate',
#    'Assamese publication associate',
#    'Punjabi Publication associate',
#    'Portuguese Translator and Proofreader',
#    'Assamese Translator',
#    'Bengali Translator',
#    'German Translator',
#    'Spanish Translator',
#    'Russian Translator',
#    'Italian Translator',
#    'Polish Translator',
#    'Tranditional Chinese Translator',
#    'French Translator',
#    'Mandarin Chinese Translator',
#    'Indonesian Translator',
#    'Korean Translator',
#    'Hebrew Translator',
#    'Japanese Translator',
#    'Arabic Translator',
#    'Vietnamese Translator',
#    'Persian Translator',
#    'Thai Translator',
#    'Portuguese Coordinator',
#    'German Coordinator',
#    'Russian Coordinator',
#    'Italian Coordinator',
#    'Polish Dubbing Artist',
#    'Traditional Chinese Coordinator',
#    'French Dubbing Artist',
#    'Mandarin Chinese Coordinator',
#    'Indonesian Coordinator',
#    'Hebrew Coordinator',
#    'Japanese Coordinator',
#    'Vietnamese Coordinator',
#    'Thai Coordinator',
#    'Withdrawn - Korean Dubbing Artist'],
#   'Teaching and Tutoring': ['English Teacher',
#    'Class Teacher',
#    'Tamil Teacher',
#    'Maths Teacher',
#    'Maths',
#    'Tamil',
#    'Library Support',
#    'Remedial class teacher/tutor',
#    'Math content developer & teacher',
#    'Nutritionist',
#    'Food researcher',
#    'Science content developer & teacher',
#    'Class teacher - junior school',
#    'Class teacher for middle school',
#    'Tamil teacher',
#    'Cricket coach',
#    'Basketball coaches',
#    'Tennis coaches',
#    'Table tennis coach',
#    'Swimming coach (male)',
#    'Badminton coach',
#    'Library and clinic support',
#    'History teacher and Cricket coach (female)',
#    'English Literature teacher',
#    'Accounts/ Commerce Teacher',
#    'Biology teacher',
#    'Sanskrit Teacher',
#    'Fine Arts teacher',
#    'Chess coach',
#    'Teach pottery wheel',
#    'Accounts/commerce teacher',
#    'Communication/Soft skill Teacher',
#    'Computer teacher',
#    'Hindi Teacher',
#    'Special Education/ Learning Support',
#    'mental health training module preparation',
#    'NEET/JEE coaching',
#    'English Content Support',
#    'Researcher'],
#   'Workshops and Training': ['Workshop / assembly facilitators',
#    'Workshop / assembly faciliatators'],
#   'Special Programs': ['Yantra Recipient-Nurturing',
#    'SP Overseas Applications'],
#   'Arts and Crafts Education': ['Art & Craft class support'],
#   'Physical Education': ['Sports trainers'],
#   'Vocational Education and Training': ['Carpentry and Invention Lab Teacher'],
#   'Online Education and Training': ['Online program delivery'],
#   'Educational Content Development': ['Media Literacy and Financial Literacy content development'],
#   'Youth Programs Coordination': ['IE - Youth College Coordinator'],
#   'Library Services': ['Librarian']},
#  'Administrative and Office Support': {'Data Entry and Management': ['Data entry operator',
#    'Data  entry operator',
#    'Data import and Form scanning',
#    'Data analyst and reporting',
#    'Data entry & Analyst',
#    'Data Entry / Analysis',
#    'Data entry',
#    'Data Entry',
#    'data entry',
#    'Transcription'],
#   'Back Office': ['Administrative Activities (Back Office)',
#    'LTV – Back office',
#    'Poornanga – Back office',
#    'MSR - Backend',
#    'Back office',
#    'Back Office Work / Front Office',
#    'Office work',
#    'Back end support personal',
#    'Backoffice',
#    'Backoffice activity',
#    'Back office support',
#    'Backoffice Support',
#    'Back Office Accounting/Store Keeping',
#    'IPC - TNK - Backoffice',
#    'IPC - TNK - Central - Backoffice',
#    'Back office Assistance',
#    'IPC - TNK - IYP / UNO / Thaimai - Back office',
#    'Library/ Office work'],
#   'Customer and Client Support': ['Communication/Soft skill',
#    'Customer Support Representatives',
#    'Call Center',
#    'Call Centre',
#    'Sales & Marketing Executive',
#    'Marketing Manager/Executive',
#    'Social Media influencer management',
#    'Marketing Volunteer',
#    'Marketing Volunteer - Marketing Analysis',
#    'Marketing Volunteer - Social Media Admin',
#    'Marketing Content writing',
#    'Social Media Content writing',
#    'Communications',
#    'Communications Support',
#    'Social Listening',
#    'Media Operations',
#    'Media networking/Public relations',
#    'Media coordinator',
#    'Social media Manager',
#    'Public Relation Manager',
#    'Donor Support',
#    'Calling Volunteer',
#    'Alumni - Helpdesk',
#    'Donor Experience Executive',
#    'Calling, Mail Handling And Supporting In the Stall',
#    'Helpline',
#    'Program Registration',
#    'Welcome Point Call Center',
#    'MSR - Call centre',
#    'Mattu Vandi Token counter - Giving tickets',
#    'Valuable Counter - Data entry and Handling visitors luggage',
#    'IE - Participant Communication Executive - IVR, Email, Chat',
#    'Valuable Counter - Data entry and Handling visitors lagguage'],
#   'Administrative Roles': ['Receptionist',
#    'Admin',
#    'Back Office Executive',
#    'Admin Coordinator',
#    'Admin Support',
#    'Backoffice Co-ordinator',
#    'Reception manager',
#    'Documentation',
#    'help Desk',
#    'Help Desk',
#    'IPC - TNK - IT',
#    'IPC - TNK - Registration',
#    'IPC - TNK - Live Streaming',
#    'IPC - TN East\t - Promotion help desk',
#    'IPC - TN East - Volunteer Nurturing Coordination Support',
#    'IPC - TN East\t - e-Media & Santosha Team Backend',
#    'IPC - TN - Promotion - Content Manager',
#    'IPC - TN - Promotion - Project Manager',
#    'IPC - TN Promotion - Video Editor',
#    'IPC - TN Promotions - Image Editor',
#    'IPC - TNK - Volunteers Nurturing',
#    'PMO Office Assistant',
#    'Accounts Assistant',
#    'Registration Coordinator',
#    'Errand Support Executive',
#    'Coordinator',
#    'Guiding Visitors',
#    'Information Center coordinator, Visitors Data Collection incharge, Material Management, Promotion executive , AV Presentation executive ,Programs facilitator & Visitors Guided tour facilitator',
#    'Information Center coordinator, Visitors Data Collection incharge, Material Management, Promotion executive , AV Presentation executive  ,Programs facilitator & Visitors Guided  tour facilitator'],
#   'Finance and Accounting': ['Finance accounts executive',
#    'Account Auditor',
#    'Accounts Manager',
#    'Accountant',
#    'Finance-support',
#    'Accounts support',
#    'Financial coordinator',
#    'Accounts audit finance',
#    'CA (Chartered Accountant)',
#    'Company Secretary',
#    'Chartered Accountant',
#    'Finance & Accounting Executive'],
#   'Human Resources and Recruitment': ['Recruitment Officer',
#    'Donor Support Executive (DSE)',
#    'Volunteer Coordination',
#    'HR Support',
#    'Recruitment'],
#   'Management': ['Manager'],
#   'Regional Administrative Support': ['APT Region Support'],
#   'Email Communication Management': ['Webinar,GOY & Samyama Email Handling',
#    'Webinar,GOY & Samyama  Email Handling'],
#   'General Support': ['Support'],
#   'Supervisory Roles': ['supervisor', 'Supervising Activities']},
#  'Safety and Security': {'Security Services': ['Safety',
#    'Security',
#    'Security office',
#    'Surveillance CCTV technician or hardware engineer',
#    'CCTV monitoring',
#    'Security support',
#    'Access Control',
#    'SSB',
#    'security office',
#    'security support',
#    'Safety Professionals'],
#   'Crowd Management': ['Yogeshwar Linga -crowd Management',
#    'Parking Area -Crowd management and  Giving tickets'],
#   'Surveillance and Technical Security': ['surveillance cctv technician or hardware engineer'],
#   'Surveillance and Monitoring': ['cctv monitoring']},
#  'Healthcare': {'Medical Professionals': ['Doctor',
#    'Allopathy Doctor',
#    'Nurse',
#    'Pharmacist',
#    'Dentist',
#    'Physiotherapist',
#    'Occupational therapist',
#    'Alopathy doctor',
#    'veterinary doctor',
#    'Paediatrician',
#    'Medicine room',
#    'Medical Volunteer',
#    'Nutritionist, Dietician',
#    'Health',
#    'Program Doctor',
#    'Veterinary Doctor']},
#  'Maintenance and Facility Services': {'Facility and Equipment Maintenance': ['Hospital maintenance and herbal garden',
#    'Electrical Maintenance support',
#    'Electrical Maintenance Support',
#    'Goushala Maintenance',
#    'Electrical Design Engineering',
#    'Electrical Design Engineer',
#    'Vehicle Maintenance',
#    'Accommodation - Maintenance',
#    'Laundry service - Gents',
#    'Laundry service - Ladies',
#    'Stay area Support',
#    'Maintenance Activities',
#    'Maintenance Support'],
#   'Cleaning and Sanitation': ['Housekeeping supervisor',
#    'Cleaning',
#    'Sanitation',
#    'Dining/Outside Suppport',
#    'Dining Support',
#    'washing helper',
#    'Ironing and segregation']},
#  'Legal and Compliance': {'Legal Services': ['For Para legal services',
#    'Law / Company Secretary background',
#    'Legal',
#    'Compliance',
#    'Advocate']},
#  'Sales, Marketing, and Customer Support': {'Social Media Management': ['Social media content Creation, promotion, Guest care',
#    'Instagram 2 stars coordinator',
#    'Tik tok coordinator',
#    'Instagram Manager For Russian',
#    'Social Media Manager for Russian',
#    'Social media content Creation, pramotion, Guest care',
#    'Instagram 2 stars coordinaotr'],
#   'Sales and Marketing Management': ['Sales Manager/ Sponsorship Manager/ Proj Mgr',
#    'Sales Manager/ Executive'],
#   'Marketing Strategy': ['Growth Strategist',
#    'Growth Manager',
#    'Growth Marketing Manager'],
#   'Digital Marketing': ['Conversion Rate Expert (landing page testing)',
#    'Conversion Rate Expert',
#    'Paid Ads Expert',
#    'Email Marketing setup',
#    'Performance Marketing (Paid ads) Manager',
#    'Paid Ads Testing'],
#   'Marketing and Promotions': ['Media /Promotion /Marketing',
#    'Promotions',
#    'Program Promotions',
#    'Promotions - Information Desk',
#    'Promotions - Offline Activations',
#    'Yantra Promotions Coordinator',
#    'Promotions coordinator',
#    'Offerings- Promotions - Campaign Manager',
#    'Marketing Executive',
#    'SURPRISER',
#    'Market Research',
#    'Marketing Manager/ Executive',
#    'Media Coordinator'],
#   'Content Creation and Writing': ['Promotions - Content Ideation'],
#   'Customer Service': ['Kshetragna - Sales and Customer Support'],
#   'Retail Sales': ['Linga Bhairavi Stall'],
#   'Sales Management': ['Sales Executive'],
#   'E-Commerce': ['E-Comm: Catalog Manager', 'E-Comm: Category Manager'],
#   'Retail Management': ['Retail Buyer'],
#   'Pre-Sales Support': ['IE - Participant Communication - Pre-Sales Chat'],
#   'Marketing Campaign Management': ['Camapgin Delivery Support']},
#  'Project and Event Management': {'Project Management': ['Project Management',
#    'Project Manager Managing IT / Engineering projects',
#    'Project Manager',
#    'Promotions Project Manager',
#    'IE - Project Manager - CSR Team'],
#   'Event Coordination and Support': ['Coordinating Activities',
#    'Event Support',
#    'Events Sorting',
#    'Promotion for Annadanam Events',
#    'Events and Guided Tours',
#    'Session Facilitator',
#    'Session Designer',
#    'Program Support Personnel',
#    'Coordinator For Ulavara thirupani (Temple cleaning activity)',
#    'Block coordinators',
#    'Billing, Serving, Supporting in production of pooja material items',
#    'Programs support',
#    'MSR - GoY',
#    'MSR - Venue preparation',
#    'Mandapam support',
#    'For Save Soil & Temple Sticker Project - Project Manager, Material Manager ,Volunteer Coordinator & training ,Social Media Manager ,Executives',
#    'Save Soil Awareness Campaign and Announcement about Dhyanalinga temple - Incharge, Material Manager, Audio Support, Demonstrator, Counter incharge, Counter Support ,Supporting volunteers',
#    'For Linga Seva Promotion - Incharge , Material manager , Counter incharge , Counter Support , Communication incharge, Nurturing Incharge, For IT Team - Video Editor , Back Office',
#    'For Save Soil & Temple Sticker Project - Project Manager,  Material Manager ,Volunteer Coordinator & training ,Social Media Manager ,Executives'],
#   'Community Outreach': ['IE - Program Outreach'],
#   'Marketing Campaign Management': ['Delivery Manager for Campaigns',
#    'Campaign Delivery Support']},
#  'Environmental and Agricultural': {'Environmental Projects': ['Project Management for Save Soil',
#    'Event Management for Save Soil',
#    'Research for Save Soil',
#    'Remote sensing & Carbon Credit Research',
#    'Soil scientist'],
#   'Agriculture and Farming': ['Solar Project R & D and Maintenance',
#    'Velliangiri Farms (Krishi Land Farm)',
#    "Maa Chandrahasa's Farm",
#    'Farm support',
#    'Crop Husbandry',
#    'Agriculture',
#    'Farming support',
#    'TN'],
#   'Agriculture and Horticulture': ['Nursery Support'],
#   'Sewage Treatment': ['STP'],
#   'Environmental Services': ['Tree care - Core team'],
#   'Agricultural Marketing and Quality Assurance': ['Agri Marketing/QA Analyst /Trainer',
#    'Agri Marketing']},
#  'Operations and Logistics': {'Logistics and Supply Chain': ['Logistics Support Executive',
#    'Transport Office executive',
#    'team technologist',
#    'Transport Shuttle coordination',
#    'Inventory Planning Manager',
#    'Warehouse and inventory manager',
#    'Asset and Inventory management',
#    'IYC Material Handling',
#    'Courier Office'],
#   'Operations Management': ['Operations Executive',
#    'Operation - Executive',
#    'Operations',
#    'Support Executive',
#    'Operations Manager',
#    'Ground Support',
#    'On ground Support'],
#   'Asset Management': ['Physical Asset'],
#   'Packaging and Distribution': ['Packaging Support']},
#  'Finance and Accounting': {'Accounting and Finance Management': ['Receipt Analyst',
#    'CA',
#    'Basic Accountancy and small application development',
#    'Basic Accountancy',
#    'MSR - Accounts'],
#   'Accounting and Materials Management': ['Dorm - Accounts and Materials']},
#  'Human Resources and Recruitment': {'Volunteer Coordination': ['Volunteer'],
#   'Training and Development': ['Human possibility',
#    'Capacity Building / Training Executive',
#    'Training Support',
#    'Training and Learning'],
#   'Recruitment and Selection': ['Kshetragna - Interview Support',
#    'SP Overseas Apps Interviewer']},
#  'Volunteer Activities': {'General Volunteer': ['Seva',
#    'Sadhana pada volunteers',
#    'Akshaya Volunteers',
#    'Sahaya',
#    'Ashram Support'],
#   'Volunteer Coordination': ['Program Volunteer Coordination - Registration support'],
#   'Spiritual and Community Support': ['Swami Nabachari Support']},
#  'Product Management and Development': {'Product Management': ['Product Manager',
#    'IE - Product Manager'],
#   'Product Development': ['Product Development']},
#  'Agricultural and Environmental Services': {'Support Services': ['Farmers Helpline']},
#  'Community and Social Services': {'Local Welfare Support': ['localwelfare various program activity',
#    'Local welfare support',
#    'localwelfare various program   activity'],
#   'Religious and Spiritual Services': ['Rituals',
#    'Bhuta Shuddhi Vivaha and Punya Pooja',
#    'Kalabhairava Karma',
#    'Coordinator For Ulavara thirupani ( Temple cleaning activity )'],
#   'NGO Support': ['IE - NGO Coordinator']},
#  'Hospitality and Food Service': {'Food Service Management': ['Dining',
#    'Dining Coordinators',
#    'MSR - Ashram program dining',
#    'Prana Danam Coordinator',
#    'Prana Danam - Serving Coordination',
#    'Prana Danam - Serving',
#    'Prana Danam support'],
#   'Accommodation Services': ['Accommodation - On ground',
#    'Accommodation - Physical entry',
#    'Long stay team',
#    'Short stay approvals',
#    'Dorm Accommodations'],
#   'Front Office Management': ['Check In',
#    'Checkin - Front Office',
#    'Pre-Check-in',
#    'Front office volunteers - Program Enquiry & Volunteer allocation',
#    'IPC - TNK - IECO Helpdesk - Front Office',
#    'Program Check-in Volunteers',
#    'Front office Volunteers - Hatha Yoga Counter',
#    'Front Office Activities'],
#   'Customer Service in Hospitality': ['Guest care support',
#    'Guest Care Support',
#    'Chandrakund support',
#    'Suryakund',
#    'IPC - TNK - Free Yoga reach - BO',
#    'Upa Yoga - Free Yoga team',
#    'Upa Yoga - TNK – Guest care',
#    'IE - Nurturing'],
#   'Hotel Management': ['Hotel Management'],
#   'Food Preparation and Cooking': ['Dining/Cook/Chef']},
#  'Engineering and Construction': {'Mechanical Engineering': ['Product/Mechanical Engineer',
#    'Mechanical/Automobile Engineer',
#    'Product/ Mechanical Engineer'],
#   'Architecture': ['Architect'],
#   'Civil and Structural Engineering': ['Civil/Structural Engineer'],
#   'Estimation': ['Civil/Estimators'],
#   'Electrical Engineering': ['Electrical Engineer'],
#   'Construction Management': ['Construction Site Supervisor',
#    'Site Supervisor',
#    'Site Superior',
#    'SITE INSPECTOR & STORE MAINTENANCE',
#    'LSP'],
#   'Fabrication and Manufacturing': ['Fabrication'],
#   'Design and CAD': ['CAD - DESIGNER & SITE INSPECTOR', 'CAD Designer'],
#   'Chemical Engineering': ['Chemical/Paint Engineer']},
#  'Customer Service and Support': {'Service Management': ['MSR - Service Department']},
#  'Non-Profit and Community Services': {'Fundraising and Development': ['Fund Raising']}}

# %%
OG_FORMAT_JOB_CLUSTERS_LATEST
# Out:
# {'Music Producer / Arranger': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Mixing Engineer': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Singers / Instrumentalists / Musicians': ('\ufeffCreative and Media',
#   'Music and Audio'),
#  'Musician ( Singer and Drummer )': ('\ufeffCreative and Media',
#   'Music and Audio'),
#  'Music/Mridhamgam/violin/Tabla/Dance': ('\ufeffCreative and Media',
#   'Music and Audio'),
#  'Carnatic Music Teacher': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Mridangam Teacher': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Piano teacher': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Tabla teacher': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Dubbing artists': ('\ufeffCreative and Media', 'Music and Audio'),
#  'German Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Russian Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Mandarin Chinese Dubbing Artist': ('\ufeffCreative and Media',
#   'Music and Audio'),
#  'Japanese Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Arabic Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Vietnamese Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Persian Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Thai Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Portuguese dubbing artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Dubbing Artist': ('\ufeffCreative and Media', 'Music and Audio'),
#  'MSR - Audio, Cottage': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Male Dubbing Voice': ('\ufeffCreative and Media', 'Music and Audio'),
#  'Photographer': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Photo Editor / Photographer': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Artist/ Illustrator': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Artificial Intelligence (AI) Art Enthusiast': ('\ufeffCreative and Media',
#   'Visual Arts'),
#  'Art Teacher': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Aesthetic/Artist/Illustrator': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Product/Furniturer/Interior Designer': ('\ufeffCreative and Media',
#   'Visual Arts'),
#  'Crafts/origami teacher': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Crafts Teacher': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Teach fashion designing': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Fashion Designer': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Jewellery Designer': ('\ufeffCreative and Media', 'Visual Arts'),
#  'Content Writer': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Creative Content Writer (Tamil/ English)': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content writer - Media': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Copywriter & Script Writer': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Copywriter + script-writer': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content Creator': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content manager': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content Strategist': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content Researcher': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content Support Executive (CSE)': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Sahaya - Content writer': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content & Communications': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content writer': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content Researcher for Tamil SM': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Content Manager': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Romanian Proofreader': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Subtitling Support': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Tamil content support': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Offerings - Promotions - Content Creator': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'IE - Content Writer - IE Core Team': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Website Blog Content Clean Up': ('\ufeffCreative and Media',
#   'Content Creation and Writing'),
#  'Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Camera Man': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Photo And Video Grapher': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Video And Photo Editing': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Video editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Photo Tagging': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Portuguese vide editor': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'German Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Russian Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Italian Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Polish Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'French Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Mandarin Chinese Video Editor': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Hebrew Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Japanese Video Editor': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Vietnamese Video Editor': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Persian Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Thai Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Indonesian Video Editor': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Video Editor / Graphic Designer': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Editors with Animation skills': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Webinars program live streaming': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'video editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Romanian Video Editor': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Arabic Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Archives Support/Photography/Videography': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'IE - Video Editor': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Archives Support/Photography/Videgraphy': ('\ufeffCreative and Media',
#   'Video and Photography'),
#  'Graphic Designer': ('\ufeffCreative and Media', 'Video and Photography'),
#  'Ad Creative Design Expert': ('\ufeffCreative and Media', 'Graphic Design'),
#  'Illustrations coordinator': ('\ufeffCreative and Media', 'Graphic Design'),
#  'designer': ('\ufeffCreative and Media', 'Graphic Design'),
#  'Mala Making (Garlands)': ('\ufeffCreative and Media', 'Arts and Crafts'),
#  'Carpentry': ('\ufeffCreative and Media', 'Arts and Crafts'),
#  'Translators': ('\ufeffCreative and Media', 'Language Translation'),
#  'Creative Director': ('\ufeffCreative and Media', 'Creative Direction'),
#  'Editor': ('\ufeffCreative and Media', 'Editing and Publishing'),
#  'Temple Production': ('\ufeffCreative and Media', 'Production and Design'),
#  'Graphic Design': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'UI Designer': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'Designer': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'Graphic Designer (package)': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'Illustrator': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'Illustrator/video editor': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'UI/UX designer': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'Visual Merchandiser': ('Information Technology and Software',
#   'UI/UX and Graphic Design'),
#  'Technical Content Writer': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'Technical support Person': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'ERP Support': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'Technical support for Sports': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'Tech support': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'Tech - Market Research': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'Technical Backend Support Assistant - IE Core Team': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'CTV gaps': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'IE - Technical Backend Support Assistant - IE Core Team': ('Information Technology and Software',
#   'Technical Support and IT Services'),
#  'Software Developer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Mobile app developer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Developer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Cloud Architect': ('Information Technology and Software',
#   'Development and Programming'),
#  'Automation & AI Python Developer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Web Developer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Project Management Tool developer (IT)': ('Information Technology and Software',
#   'Development and Programming'),
#  'Mobile Health Clinic': ('Information Technology and Software',
#   'Development and Programming'),
#  'IT Hardware engineer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Devops Engineer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Live Streaming Engineer': ('Information Technology and Software',
#   'Development and Programming'),
#  'Cyber Security Analyst': ('Information Technology and Software',
#   'Cybersecurity'),
#  'Cyber Security Engineer': ('Information Technology and Software',
#   'Cybersecurity'),
#  'Technical SEO': ('Information Technology and Software',
#   'SEO and Digital Marketing'),
#  'Google Tag Manager / Google Analytics Specialist': ('Information Technology and Software',
#   'SEO and Digital Marketing'),
#  'SM Analytics': ('Information Technology and Software',
#   'SEO and Digital Marketing'),
#  'YT SEO': ('Information Technology and Software',
#   'SEO and Digital Marketing'),
#  'Live Streaming Support & Digital Marketing support.': ('Information Technology and Software',
#   'SEO and Digital Marketing'),
#  'Network Engineer': ('Information Technology and Software',
#   'Network and Systems'),
#  'Server Engineer': ('Information Technology and Software',
#   'Network and Systems'),
#  'End user computing / Desktop Support Engineer': ('Information Technology and Software',
#   'Network and Systems'),
#  'IT Support': ('Information Technology and Software', 'Network and Systems'),
#  'Data Scientist': ('Information Technology and Software',
#   'Data Science and Analytics'),
#  'Data Analyst': ('Information Technology and Software',
#   'Data Science and Analytics'),
#  'Data and research analyst': ('Information Technology and Software',
#   'Data Science and Analytics'),
#  'Tech - Data Analytics': ('Information Technology and Software',
#   'Data Science and Analytics'),
#  'IE - Data Analyst - IE Core Team': ('Information Technology and Software',
#   'Data Science and Analytics'),
#  'Artificial Intelligence (AI) Enthusiast': ('Information Technology and Software',
#   'Data Science and Analytics'),
#  'UX Designer': ('Information Technology and Software', 'UI/UX Design'),
#  'UX Desinger': ('Information Technology and Software', 'UI/UX Design'),
#  'Business Analyst (BA)': ('Information Technology and Software',
#   'Business Analysis and Strategy'),
#  'Business analyst': ('Information Technology and Software',
#   'Business Analysis and Strategy'),
#  'Business Analyst': ('Information Technology and Software',
#   'Business Analysis and Strategy'),
#  'Business strategist': ('Information Technology and Software',
#   'Business Analysis and Strategy'),
#  'Platform Managers': ('Information Technology and Software',
#   'Platform Management'),
#  'Platform Manager for Tamil SM': ('Information Technology and Software',
#   'Platform Management'),
#  'Platform Manager': ('Information Technology and Software',
#   'Platform Management'),
#  'Sadhguru Sahabhagi and IT': ('Information Technology and Software',
#   'IT Management'),
#  'Offerings - IT': ('Information Technology and Software', 'IT Management'),
#  'Applications - Audio calls': ('Information Technology and Software',
#   'Customer and Technical Support'),
#  'Applications - Video calls': ('Information Technology and Software',
#   'Customer and Technical Support'),
#  'Whatsapp coordinator': ('Information Technology and Software',
#   'Social Media Management'),
#  'Business Analyst and Software Tester': ('Information Technology and Software',
#   'Quality Assurance and Testing'),
#  'Test Engineer': ('Information Technology and Software',
#   'Quality Assurance and Testing'),
#  'Website building and management': ('Information Technology and Software',
#   'Web Development and Management'),
#  'Form Building': ('Information Technology and Software',
#   'Software Development'),
#  'Report -MIS': ('Information Technology and Software',
#   'Management Information Systems'),
#  'Spanish Video Editor': ('Education and Training',
#   'Language and Translation'),
#  'Traditional Chinese Video Editor': ('Education and Training',
#   'Language and Translation'),
#  'Korean Video Editor': ('Education and Training', 'Language and Translation'),
#  'Translator': ('Education and Training', 'Language and Translation'),
#  'Nepali Translator': ('Education and Training', 'Language and Translation'),
#  'Punjabi Translator': ('Education and Training', 'Language and Translation'),
#  'Odia Translator': ('Education and Training', 'Language and Translation'),
#  'Gujarati Translator': ('Education and Training', 'Language and Translation'),
#  'Malayalam Translator': ('Education and Training',
#   'Language and Translation'),
#  'Marathi Translator': ('Education and Training', 'Language and Translation'),
#  'Hindi Translator': ('Education and Training', 'Language and Translation'),
#  'Portuguese Translator': ('Education and Training',
#   'Language and Translation'),
#  'Telugu Translator': ('Education and Training', 'Language and Translation'),
#  'Gujarati publication associate': ('Education and Training',
#   'Language and Translation'),
#  'Odia Publication Associate': ('Education and Training',
#   'Language and Translation'),
#  'Nepali Publication Associate': ('Education and Training',
#   'Language and Translation'),
#  'Kannada Publication associate': ('Education and Training',
#   'Language and Translation'),
#  'Hindi Publication associate': ('Education and Training',
#   'Language and Translation'),
#  'Marathi Publication Associate': ('Education and Training',
#   'Language and Translation'),
#  'Telugu Publication Associate': ('Education and Training',
#   'Language and Translation'),
#  'Bengali Publication associate': ('Education and Training',
#   'Language and Translation'),
#  'Malayalam publication associate': ('Education and Training',
#   'Language and Translation'),
#  'Assamese publication associate': ('Education and Training',
#   'Language and Translation'),
#  'Punjabi Publication associate': ('Education and Training',
#   'Language and Translation'),
#  'Portuguese Translator and Proofreader': ('Education and Training',
#   'Language and Translation'),
#  'Assamese Translator': ('Education and Training', 'Language and Translation'),
#  'Bengali Translator': ('Education and Training', 'Language and Translation'),
#  'German Translator': ('Education and Training', 'Language and Translation'),
#  'Spanish Translator': ('Education and Training', 'Language and Translation'),
#  'Russian Translator': ('Education and Training', 'Language and Translation'),
#  'Italian Translator': ('Education and Training', 'Language and Translation'),
#  'Polish Translator': ('Education and Training', 'Language and Translation'),
#  'Tranditional Chinese Translator': ('Education and Training',
#   'Language and Translation'),
#  'French Translator': ('Education and Training', 'Language and Translation'),
#  'Mandarin Chinese Translator': ('Education and Training',
#   'Language and Translation'),
#  'Indonesian Translator': ('Education and Training',
#   'Language and Translation'),
#  'Korean Translator': ('Education and Training', 'Language and Translation'),
#  'Hebrew Translator': ('Education and Training', 'Language and Translation'),
#  'Japanese Translator': ('Education and Training', 'Language and Translation'),
#  'Arabic Translator': ('Education and Training', 'Language and Translation'),
#  'Vietnamese Translator': ('Education and Training',
#   'Language and Translation'),
#  'Persian Translator': ('Education and Training', 'Language and Translation'),
#  'Thai Translator': ('Education and Training', 'Language and Translation'),
#  'Portuguese Coordinator': ('Education and Training',
#   'Language and Translation'),
#  'German Coordinator': ('Education and Training', 'Language and Translation'),
#  'Russian Coordinator': ('Education and Training', 'Language and Translation'),
#  'Italian Coordinator': ('Education and Training', 'Language and Translation'),
#  'Polish Dubbing Artist': ('Education and Training',
#   'Language and Translation'),
#  'Traditional Chinese Coordinator': ('Education and Training',
#   'Language and Translation'),
#  'French Dubbing Artist': ('Education and Training',
#   'Language and Translation'),
#  'Mandarin Chinese Coordinator': ('Education and Training',
#   'Language and Translation'),
#  'Indonesian Coordinator': ('Education and Training',
#   'Language and Translation'),
#  'Hebrew Coordinator': ('Education and Training', 'Language and Translation'),
#  'Japanese Coordinator': ('Education and Training',
#   'Language and Translation'),
#  'Vietnamese Coordinator': ('Education and Training',
#   'Language and Translation'),
#  'Thai Coordinator': ('Education and Training', 'Language and Translation'),
#  'Withdrawn - Korean Dubbing Artist': ('Education and Training',
#   'Language and Translation'),
#  'English Teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Class Teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Tamil Teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Maths Teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Maths': ('Education and Training', 'Teaching and Tutoring'),
#  'Tamil': ('Education and Training', 'Teaching and Tutoring'),
#  'Library Support': ('Education and Training', 'Teaching and Tutoring'),
#  'Remedial class teacher/tutor': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Math content developer & teacher': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Nutritionist': ('Education and Training', 'Teaching and Tutoring'),
#  'Food researcher': ('Education and Training', 'Teaching and Tutoring'),
#  'Science content developer & teacher': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Class teacher - junior school': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Class teacher for middle school': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Tamil teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Cricket coach': ('Education and Training', 'Teaching and Tutoring'),
#  'Basketball coaches': ('Education and Training', 'Teaching and Tutoring'),
#  'Tennis coaches': ('Education and Training', 'Teaching and Tutoring'),
#  'Table tennis coach': ('Education and Training', 'Teaching and Tutoring'),
#  'Swimming coach (male)': ('Education and Training', 'Teaching and Tutoring'),
#  'Badminton coach': ('Education and Training', 'Teaching and Tutoring'),
#  'Library and clinic support': ('Education and Training',
#   'Teaching and Tutoring'),
#  'History teacher and Cricket coach (female)': ('Education and Training',
#   'Teaching and Tutoring'),
#  'English Literature teacher': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Accounts/ Commerce Teacher': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Biology teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Sanskrit Teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Fine Arts teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Chess coach': ('Education and Training', 'Teaching and Tutoring'),
#  'Teach pottery wheel': ('Education and Training', 'Teaching and Tutoring'),
#  'Accounts/commerce teacher': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Communication/Soft skill Teacher': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Computer teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Hindi Teacher': ('Education and Training', 'Teaching and Tutoring'),
#  'Special Education/ Learning Support': ('Education and Training',
#   'Teaching and Tutoring'),
#  'mental health training module preparation': ('Education and Training',
#   'Teaching and Tutoring'),
#  'NEET/JEE coaching': ('Education and Training', 'Teaching and Tutoring'),
#  'English Content Support': ('Education and Training',
#   'Teaching and Tutoring'),
#  'Researcher': ('Education and Training', 'Teaching and Tutoring'),
#  'Workshop / assembly facilitators': ('Education and Training',
#   'Workshops and Training'),
#  'Workshop / assembly faciliatators': ('Education and Training',
#   'Workshops and Training'),
#  'Yantra Recipient-Nurturing': ('Education and Training', 'Special Programs'),
#  'SP Overseas Applications': ('Education and Training', 'Special Programs'),
#  'Art & Craft class support': ('Education and Training',
#   'Arts and Crafts Education'),
#  'Sports trainers': ('Education and Training', 'Physical Education'),
#  'Carpentry and Invention Lab Teacher': ('Education and Training',
#   'Vocational Education and Training'),
#  'Online program delivery': ('Education and Training',
#   'Online Education and Training'),
#  'Media Literacy and Financial Literacy content development': ('Education and Training',
#   'Educational Content Development'),
#  'IE - Youth College Coordinator': ('Education and Training',
#   'Youth Programs Coordination'),
#  'Librarian': ('Education and Training', 'Library Services'),
#  'Data entry operator': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Data  entry operator': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Data import and Form scanning': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Data analyst and reporting': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Data entry & Analyst': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Data Entry / Analysis': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Data entry': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Data Entry': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'data entry': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Transcription': ('Administrative and Office Support',
#   'Data Entry and Management'),
#  'Administrative Activities (Back Office)': ('Administrative and Office Support',
#   'Back Office'),
#  'LTV – Back office': ('Administrative and Office Support', 'Back Office'),
#  'Poornanga – Back office': ('Administrative and Office Support',
#   'Back Office'),
#  'MSR - Backend': ('Administrative and Office Support', 'Back Office'),
#  'Back office': ('Administrative and Office Support', 'Back Office'),
#  'Back Office Work / Front Office': ('Administrative and Office Support',
#   'Back Office'),
#  'Office work': ('Administrative and Office Support', 'Back Office'),
#  'Back end support personal': ('Administrative and Office Support',
#   'Back Office'),
#  'Backoffice': ('Administrative and Office Support', 'Back Office'),
#  'Backoffice activity': ('Administrative and Office Support', 'Back Office'),
#  'Back office support': ('Administrative and Office Support', 'Back Office'),
#  'Backoffice Support': ('Administrative and Office Support', 'Back Office'),
#  'Back Office Accounting/Store Keeping': ('Administrative and Office Support',
#   'Back Office'),
#  'IPC - TNK - Backoffice': ('Administrative and Office Support',
#   'Back Office'),
#  'IPC - TNK - Central - Backoffice': ('Administrative and Office Support',
#   'Back Office'),
#  'Back office Assistance': ('Administrative and Office Support',
#   'Back Office'),
#  'IPC - TNK - IYP / UNO / Thaimai - Back office': ('Administrative and Office Support',
#   'Back Office'),
#  'Library/ Office work': ('Administrative and Office Support', 'Back Office'),
#  'Communication/Soft skill': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Customer Support Representatives': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Call Center': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Call Centre': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Sales & Marketing Executive': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Marketing Manager/Executive': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Social Media influencer management': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Marketing Volunteer': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Marketing Volunteer - Marketing Analysis': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Marketing Volunteer - Social Media Admin': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Marketing Content writing': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Social Media Content writing': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Communications': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Communications Support': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Social Listening': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Media Operations': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Media networking/Public relations': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Media coordinator': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Social media Manager': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Public Relation Manager': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Donor Support': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Calling Volunteer': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Alumni - Helpdesk': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Donor Experience Executive': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Calling, Mail Handling And Supporting In the Stall': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Helpline': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Program Registration': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Welcome Point Call Center': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'MSR - Call centre': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Mattu Vandi Token counter - Giving tickets': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Valuable Counter - Data entry and Handling visitors luggage': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'IE - Participant Communication Executive - IVR, Email, Chat': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Valuable Counter - Data entry and Handling visitors lagguage': ('Administrative and Office Support',
#   'Customer and Client Support'),
#  'Receptionist': ('Administrative and Office Support', 'Administrative Roles'),
#  'Admin': ('Administrative and Office Support', 'Administrative Roles'),
#  'Back Office Executive': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Admin Coordinator': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Admin Support': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Backoffice Co-ordinator': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Reception manager': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Documentation': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'help Desk': ('Administrative and Office Support', 'Administrative Roles'),
#  'Help Desk': ('Administrative and Office Support', 'Administrative Roles'),
#  'IPC - TNK - IT': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TNK - Registration': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TNK - Live Streaming': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TN East\t - Promotion help desk': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TN East - Volunteer Nurturing Coordination Support': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TN East\t - e-Media & Santosha Team Backend': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TN - Promotion - Content Manager': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TN - Promotion - Project Manager': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TN Promotion - Video Editor': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TN Promotions - Image Editor': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'IPC - TNK - Volunteers Nurturing': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'PMO Office Assistant': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Accounts Assistant': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Registration Coordinator': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Errand Support Executive': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Coordinator': ('Administrative and Office Support', 'Administrative Roles'),
#  'Guiding Visitors': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Information Center coordinator, Visitors Data Collection incharge, Material Management, Promotion executive , AV Presentation executive ,Programs facilitator & Visitors Guided tour facilitator': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Information Center coordinator, Visitors Data Collection incharge, Material Management, Promotion executive , AV Presentation executive  ,Programs facilitator & Visitors Guided  tour facilitator': ('Administrative and Office Support',
#   'Administrative Roles'),
#  'Finance accounts executive': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Account Auditor': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Accounts Manager': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Accountant': ('Administrative and Office Support', 'Finance and Accounting'),
#  'Finance-support': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Accounts support': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Financial coordinator': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Accounts audit finance': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'CA (Chartered Accountant)': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Company Secretary': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Chartered Accountant': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Finance & Accounting Executive': ('Administrative and Office Support',
#   'Finance and Accounting'),
#  'Recruitment Officer': ('Administrative and Office Support',
#   'Human Resources and Recruitment'),
#  'Donor Support Executive (DSE)': ('Administrative and Office Support',
#   'Human Resources and Recruitment'),
#  'Volunteer Coordination': ('Administrative and Office Support',
#   'Human Resources and Recruitment'),
#  'HR Support': ('Administrative and Office Support',
#   'Human Resources and Recruitment'),
#  'Recruitment': ('Administrative and Office Support',
#   'Human Resources and Recruitment'),
#  'Manager': ('Administrative and Office Support', 'Management'),
#  'APT Region Support': ('Administrative and Office Support',
#   'Regional Administrative Support'),
#  'Webinar,GOY & Samyama Email Handling': ('Administrative and Office Support',
#   'Email Communication Management'),
#  'Webinar,GOY & Samyama  Email Handling': ('Administrative and Office Support',
#   'Email Communication Management'),
#  'Support': ('Administrative and Office Support', 'General Support'),
#  'supervisor': ('Administrative and Office Support', 'Supervisory Roles'),
#  'Supervising Activities': ('Administrative and Office Support',
#   'Supervisory Roles'),
#  'Safety': ('Safety and Security', 'Security Services'),
#  'Security': ('Safety and Security', 'Security Services'),
#  'Security office': ('Safety and Security', 'Security Services'),
#  'Surveillance CCTV technician or hardware engineer': ('Safety and Security',
#   'Security Services'),
#  'CCTV monitoring': ('Safety and Security', 'Security Services'),
#  'Security support': ('Safety and Security', 'Security Services'),
#  'Access Control': ('Safety and Security', 'Security Services'),
#  'SSB': ('Safety and Security', 'Security Services'),
#  'security office': ('Safety and Security', 'Security Services'),
#  'security support': ('Safety and Security', 'Security Services'),
#  'Safety Professionals': ('Safety and Security', 'Security Services'),
#  'Yogeshwar Linga -crowd Management': ('Safety and Security',
#   'Crowd Management'),
#  'Parking Area -Crowd management and  Giving tickets': ('Safety and Security',
#   'Crowd Management'),
#  'surveillance cctv technician or hardware engineer': ('Safety and Security',
#   'Surveillance and Technical Security'),
#  'cctv monitoring': ('Safety and Security', 'Surveillance and Monitoring'),
#  'Doctor': ('Healthcare', 'Medical Professionals'),
#  'Allopathy Doctor': ('Healthcare', 'Medical Professionals'),
#  'Nurse': ('Healthcare', 'Medical Professionals'),
#  'Pharmacist': ('Healthcare', 'Medical Professionals'),
#  'Dentist': ('Healthcare', 'Medical Professionals'),
#  'Physiotherapist': ('Healthcare', 'Medical Professionals'),
#  'Occupational therapist': ('Healthcare', 'Medical Professionals'),
#  'Alopathy doctor': ('Healthcare', 'Medical Professionals'),
#  'veterinary doctor': ('Healthcare', 'Medical Professionals'),
#  'Paediatrician': ('Healthcare', 'Medical Professionals'),
#  'Medicine room': ('Healthcare', 'Medical Professionals'),
#  'Medical Volunteer': ('Healthcare', 'Medical Professionals'),
#  'Nutritionist, Dietician': ('Healthcare', 'Medical Professionals'),
#  'Health': ('Healthcare', 'Medical Professionals'),
#  'Program Doctor': ('Healthcare', 'Medical Professionals'),
#  'Veterinary Doctor': ('Healthcare', 'Medical Professionals'),
#  'Hospital maintenance and herbal garden': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Electrical Maintenance support': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Electrical Maintenance Support': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Goushala Maintenance': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Electrical Design Engineering': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Electrical Design Engineer': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Vehicle Maintenance': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Accommodation - Maintenance': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Laundry service - Gents': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Laundry service - Ladies': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Stay area Support': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Maintenance Activities': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Maintenance Support': ('Maintenance and Facility Services',
#   'Facility and Equipment Maintenance'),
#  'Housekeeping supervisor': ('Maintenance and Facility Services',
#   'Cleaning and Sanitation'),
#  'Cleaning': ('Maintenance and Facility Services', 'Cleaning and Sanitation'),
#  'Sanitation': ('Maintenance and Facility Services',
#   'Cleaning and Sanitation'),
#  'Dining/Outside Suppport': ('Maintenance and Facility Services',
#   'Cleaning and Sanitation'),
#  'Dining Support': ('Maintenance and Facility Services',
#   'Cleaning and Sanitation'),
#  'washing helper': ('Maintenance and Facility Services',
#   'Cleaning and Sanitation'),
#  'Ironing and segregation': ('Maintenance and Facility Services',
#   'Cleaning and Sanitation'),
#  'For Para legal services': ('Legal and Compliance', 'Legal Services'),
#  'Law / Company Secretary background': ('Legal and Compliance',
#   'Legal Services'),
#  'Legal': ('Legal and Compliance', 'Legal Services'),
#  'Compliance': ('Legal and Compliance', 'Legal Services'),
#  'Advocate': ('Legal and Compliance', 'Legal Services'),
#  'Social media content Creation, promotion, Guest care': ('Sales, Marketing, and Customer Support',
#   'Social Media Management'),
#  'Instagram 2 stars coordinator': ('Sales, Marketing, and Customer Support',
#   'Social Media Management'),
#  'Tik tok coordinator': ('Sales, Marketing, and Customer Support',
#   'Social Media Management'),
#  'Instagram Manager For Russian': ('Sales, Marketing, and Customer Support',
#   'Social Media Management'),
#  'Social Media Manager for Russian': ('Sales, Marketing, and Customer Support',
#   'Social Media Management'),
#  'Social media content Creation, pramotion, Guest care': ('Sales, Marketing, and Customer Support',
#   'Social Media Management'),
#  'Instagram 2 stars coordinaotr': ('Sales, Marketing, and Customer Support',
#   'Social Media Management'),
#  'Sales Manager/ Sponsorship Manager/ Proj Mgr': ('Sales, Marketing, and Customer Support',
#   'Sales and Marketing Management'),
#  'Sales Manager/ Executive': ('Sales, Marketing, and Customer Support',
#   'Sales and Marketing Management'),
#  'Growth Strategist': ('Sales, Marketing, and Customer Support',
#   'Marketing Strategy'),
#  'Growth Manager': ('Sales, Marketing, and Customer Support',
#   'Marketing Strategy'),
#  'Growth Marketing Manager': ('Sales, Marketing, and Customer Support',
#   'Marketing Strategy'),
#  'Conversion Rate Expert (landing page testing)': ('Sales, Marketing, and Customer Support',
#   'Digital Marketing'),
#  'Conversion Rate Expert': ('Sales, Marketing, and Customer Support',
#   'Digital Marketing'),
#  'Paid Ads Expert': ('Sales, Marketing, and Customer Support',
#   'Digital Marketing'),
#  'Email Marketing setup': ('Sales, Marketing, and Customer Support',
#   'Digital Marketing'),
#  'Performance Marketing (Paid ads) Manager': ('Sales, Marketing, and Customer Support',
#   'Digital Marketing'),
#  'Paid Ads Testing': ('Sales, Marketing, and Customer Support',
#   'Digital Marketing'),
#  'Media /Promotion /Marketing': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Promotions': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Program Promotions': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Promotions - Information Desk': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Promotions - Offline Activations': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Yantra Promotions Coordinator': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Promotions coordinator': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Offerings- Promotions - Campaign Manager': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Marketing Executive': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'SURPRISER': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Market Research': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Marketing Manager/ Executive': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Media Coordinator': ('Sales, Marketing, and Customer Support',
#   'Marketing and Promotions'),
#  'Promotions - Content Ideation': ('Sales, Marketing, and Customer Support',
#   'Content Creation and Writing'),
#  'Kshetragna - Sales and Customer Support': ('Sales, Marketing, and Customer Support',
#   'Customer Service'),
#  'Linga Bhairavi Stall': ('Sales, Marketing, and Customer Support',
#   'Retail Sales'),
#  'Sales Executive': ('Sales, Marketing, and Customer Support',
#   'Sales Management'),
#  'E-Comm: Catalog Manager': ('Sales, Marketing, and Customer Support',
#   'E-Commerce'),
#  'E-Comm: Category Manager': ('Sales, Marketing, and Customer Support',
#   'E-Commerce'),
#  'Retail Buyer': ('Sales, Marketing, and Customer Support',
#   'Retail Management'),
#  'IE - Participant Communication - Pre-Sales Chat': ('Sales, Marketing, and Customer Support',
#   'Pre-Sales Support'),
#  'Camapgin Delivery Support': ('Sales, Marketing, and Customer Support',
#   'Marketing Campaign Management'),
#  'Project Management': ('Project and Event Management', 'Project Management'),
#  'Project Manager Managing IT / Engineering projects': ('Project and Event Management',
#   'Project Management'),
#  'Project Manager': ('Project and Event Management', 'Project Management'),
#  'Promotions Project Manager': ('Project and Event Management',
#   'Project Management'),
#  'IE - Project Manager - CSR Team': ('Project and Event Management',
#   'Project Management'),
#  'Coordinating Activities': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Event Support': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Events Sorting': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Promotion for Annadanam Events': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Events and Guided Tours': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Session Facilitator': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Session Designer': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Program Support Personnel': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Coordinator For Ulavara thirupani (Temple cleaning activity)': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Block coordinators': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Billing, Serving, Supporting in production of pooja material items': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Programs support': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'MSR - GoY': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'MSR - Venue preparation': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Mandapam support': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'For Save Soil & Temple Sticker Project - Project Manager, Material Manager ,Volunteer Coordinator & training ,Social Media Manager ,Executives': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'Save Soil Awareness Campaign and Announcement about Dhyanalinga temple - Incharge, Material Manager, Audio Support, Demonstrator, Counter incharge, Counter Support ,Supporting volunteers': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'For Linga Seva Promotion - Incharge , Material manager , Counter incharge , Counter Support , Communication incharge, Nurturing Incharge, For IT Team - Video Editor , Back Office': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'For Save Soil & Temple Sticker Project - Project Manager,  Material Manager ,Volunteer Coordinator & training ,Social Media Manager ,Executives': ('Project and Event Management',
#   'Event Coordination and Support'),
#  'IE - Program Outreach': ('Project and Event Management',
#   'Community Outreach'),
#  'Delivery Manager for Campaigns': ('Project and Event Management',
#   'Marketing Campaign Management'),
#  'Campaign Delivery Support': ('Project and Event Management',
#   'Marketing Campaign Management'),
#  'Project Management for Save Soil': ('Environmental and Agricultural',
#   'Environmental Projects'),
#  'Event Management for Save Soil': ('Environmental and Agricultural',
#   'Environmental Projects'),
#  'Research for Save Soil': ('Environmental and Agricultural',
#   'Environmental Projects'),
#  'Remote sensing & Carbon Credit Research': ('Environmental and Agricultural',
#   'Environmental Projects'),
#  'Soil scientist': ('Environmental and Agricultural',
#   'Environmental Projects'),
#  'Solar Project R & D and Maintenance': ('Environmental and Agricultural',
#   'Agriculture and Farming'),
#  'Velliangiri Farms (Krishi Land Farm)': ('Environmental and Agricultural',
#   'Agriculture and Farming'),
#  "Maa Chandrahasa's Farm": ('Environmental and Agricultural',
#   'Agriculture and Farming'),
#  'Farm support': ('Environmental and Agricultural', 'Agriculture and Farming'),
#  'Crop Husbandry': ('Environmental and Agricultural',
#   'Agriculture and Farming'),
#  'Agriculture': ('Environmental and Agricultural', 'Agriculture and Farming'),
#  'Farming support': ('Environmental and Agricultural',
#   'Agriculture and Farming'),
#  'TN': ('Environmental and Agricultural', 'Agriculture and Farming'),
#  'Nursery Support': ('Environmental and Agricultural',
#   'Agriculture and Horticulture'),
#  'STP': ('Environmental and Agricultural', 'Sewage Treatment'),
#  'Tree care - Core team': ('Environmental and Agricultural',
#   'Environmental Services'),
#  'Agri Marketing/QA Analyst /Trainer': ('Environmental and Agricultural',
#   'Agricultural Marketing and Quality Assurance'),
#  'Agri Marketing': ('Environmental and Agricultural',
#   'Agricultural Marketing and Quality Assurance'),
#  'Logistics Support Executive': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'Transport Office executive': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'team technologist': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'Transport Shuttle coordination': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'Inventory Planning Manager': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'Warehouse and inventory manager': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'Asset and Inventory management': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'IYC Material Handling': ('Operations and Logistics',
#   'Logistics and Supply Chain'),
#  'Courier Office': ('Operations and Logistics', 'Logistics and Supply Chain'),
#  'Operations Executive': ('Operations and Logistics', 'Operations Management'),
#  'Operation - Executive': ('Operations and Logistics',
#   'Operations Management'),
#  'Operations': ('Operations and Logistics', 'Operations Management'),
#  'Support Executive': ('Operations and Logistics', 'Operations Management'),
#  'Operations Manager': ('Operations and Logistics', 'Operations Management'),
#  'Ground Support': ('Operations and Logistics', 'Operations Management'),
#  'On ground Support': ('Operations and Logistics', 'Operations Management'),
#  'Physical Asset': ('Operations and Logistics', 'Asset Management'),
#  'Packaging Support': ('Operations and Logistics',
#   'Packaging and Distribution'),
#  'Receipt Analyst': ('Finance and Accounting',
#   'Accounting and Finance Management'),
#  'CA': ('Finance and Accounting', 'Accounting and Finance Management'),
#  'Basic Accountancy and small application development': ('Finance and Accounting',
#   'Accounting and Finance Management'),
#  'Basic Accountancy': ('Finance and Accounting',
#   'Accounting and Finance Management'),
#  'MSR - Accounts': ('Finance and Accounting',
#   'Accounting and Finance Management'),
#  'Dorm - Accounts and Materials': ('Finance and Accounting',
#   'Accounting and Materials Management'),
#  'Volunteer': ('Human Resources and Recruitment', 'Volunteer Coordination'),
#  'Human possibility': ('Human Resources and Recruitment',
#   'Training and Development'),
#  'Capacity Building / Training Executive': ('Human Resources and Recruitment',
#   'Training and Development'),
#  'Training Support': ('Human Resources and Recruitment',
#   'Training and Development'),
#  'Training and Learning': ('Human Resources and Recruitment',
#   'Training and Development'),
#  'Kshetragna - Interview Support': ('Human Resources and Recruitment',
#   'Recruitment and Selection'),
#  'SP Overseas Apps Interviewer': ('Human Resources and Recruitment',
#   'Recruitment and Selection'),
#  'Seva': ('Volunteer Activities', 'General Volunteer'),
#  'Sadhana pada volunteers': ('Volunteer Activities', 'General Volunteer'),
#  'Akshaya Volunteers': ('Volunteer Activities', 'General Volunteer'),
#  'Sahaya': ('Volunteer Activities', 'General Volunteer'),
#  'Ashram Support': ('Volunteer Activities', 'General Volunteer'),
#  'Program Volunteer Coordination - Registration support': ('Volunteer Activities',
#   'Volunteer Coordination'),
#  'Swami Nabachari Support': ('Volunteer Activities',
#   'Spiritual and Community Support'),
#  'Product Manager': ('Product Management and Development',
#   'Product Management'),
#  'IE - Product Manager': ('Product Management and Development',
#   'Product Management'),
#  'Product Development': ('Product Management and Development',
#   'Product Development'),
#  'Farmers Helpline': ('Agricultural and Environmental Services',
#   'Support Services'),
#  'localwelfare various program activity': ('Community and Social Services',
#   'Local Welfare Support'),
#  'Local welfare support': ('Community and Social Services',
#   'Local Welfare Support'),
#  'localwelfare various program   activity': ('Community and Social Services',
#   'Local Welfare Support'),
#  'Rituals': ('Community and Social Services',
#   'Religious and Spiritual Services'),
#  'Bhuta Shuddhi Vivaha and Punya Pooja': ('Community and Social Services',
#   'Religious and Spiritual Services'),
#  'Kalabhairava Karma': ('Community and Social Services',
#   'Religious and Spiritual Services'),
#  'Coordinator For Ulavara thirupani ( Temple cleaning activity )': ('Community and Social Services',
#   'Religious and Spiritual Services'),
#  'IE - NGO Coordinator': ('Community and Social Services', 'NGO Support'),
#  'Dining': ('Hospitality and Food Service', 'Food Service Management'),
#  'Dining Coordinators': ('Hospitality and Food Service',
#   'Food Service Management'),
#  'MSR - Ashram program dining': ('Hospitality and Food Service',
#   'Food Service Management'),
#  'Prana Danam Coordinator': ('Hospitality and Food Service',
#   'Food Service Management'),
#  'Prana Danam - Serving Coordination': ('Hospitality and Food Service',
#   'Food Service Management'),
#  'Prana Danam - Serving': ('Hospitality and Food Service',
#   'Food Service Management'),
#  'Prana Danam support': ('Hospitality and Food Service',
#   'Food Service Management'),
#  'Accommodation - On ground': ('Hospitality and Food Service',
#   'Accommodation Services'),
#  'Accommodation - Physical entry': ('Hospitality and Food Service',
#   'Accommodation Services'),
#  'Long stay team': ('Hospitality and Food Service', 'Accommodation Services'),
#  'Short stay approvals': ('Hospitality and Food Service',
#   'Accommodation Services'),
#  'Dorm Accommodations': ('Hospitality and Food Service',
#   'Accommodation Services'),
#  'Check In': ('Hospitality and Food Service', 'Front Office Management'),
#  'Checkin - Front Office': ('Hospitality and Food Service',
#   'Front Office Management'),
#  'Pre-Check-in': ('Hospitality and Food Service', 'Front Office Management'),
#  'Front office volunteers - Program Enquiry & Volunteer allocation': ('Hospitality and Food Service',
#   'Front Office Management'),
#  'IPC - TNK - IECO Helpdesk - Front Office': ('Hospitality and Food Service',
#   'Front Office Management'),
#  'Program Check-in Volunteers': ('Hospitality and Food Service',
#   'Front Office Management'),
#  'Front office Volunteers - Hatha Yoga Counter': ('Hospitality and Food Service',
#   'Front Office Management'),
#  'Front Office Activities': ('Hospitality and Food Service',
#   'Front Office Management'),
#  'Guest care support': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'Guest Care Support': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'Chandrakund support': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'Suryakund': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'IPC - TNK - Free Yoga reach - BO': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'Upa Yoga - Free Yoga team': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'Upa Yoga - TNK – Guest care': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'IE - Nurturing': ('Hospitality and Food Service',
#   'Customer Service in Hospitality'),
#  'Hotel Management': ('Hospitality and Food Service', 'Hotel Management'),
#  'Dining/Cook/Chef': ('Hospitality and Food Service',
#   'Food Preparation and Cooking'),
#  'Product/Mechanical Engineer': ('Engineering and Construction',
#   'Mechanical Engineering'),
#  'Mechanical/Automobile Engineer': ('Engineering and Construction',
#   'Mechanical Engineering'),
#  'Product/ Mechanical Engineer': ('Engineering and Construction',
#   'Mechanical Engineering'),
#  'Architect': ('Engineering and Construction', 'Architecture'),
#  'Civil/Structural Engineer': ('Engineering and Construction',
#   'Civil and Structural Engineering'),
#  'Civil/Estimators': ('Engineering and Construction', 'Estimation'),
#  'Electrical Engineer': ('Engineering and Construction',
#   'Electrical Engineering'),
#  'Construction Site Supervisor': ('Engineering and Construction',
#   'Construction Management'),
#  'Site Supervisor': ('Engineering and Construction',
#   'Construction Management'),
#  'Site Superior': ('Engineering and Construction', 'Construction Management'),
#  'SITE INSPECTOR & STORE MAINTENANCE': ('Engineering and Construction',
#   'Construction Management'),
#  'LSP': ('Engineering and Construction', 'Construction Management'),
#  'Fabrication': ('Engineering and Construction',
#   'Fabrication and Manufacturing'),
#  'CAD - DESIGNER & SITE INSPECTOR': ('Engineering and Construction',
#   'Design and CAD'),
#  'CAD Designer': ('Engineering and Construction', 'Design and CAD'),
#  'Chemical/Paint Engineer': ('Engineering and Construction',
#   'Chemical Engineering'),
#  'MSR - Service Department': ('Customer Service and Support',
#   'Service Management'),
#  'Fund Raising': ('Non-Profit and Community Services',
#   'Fundraising and Development')}

# %%
def process_file(file_path):
    # Load the Excel file
    df = pd.read_excel(file_path)
    
    # Sort the DataFrame by SP_ID if it's not already sorted
    df = df.sort_values(by='SP_ID')
    
    # Add a 'Row Number' column, which is the row number within each SP_ID group
    df['Row Number'] = df.groupby('SP_ID').cumcount() + 1


    ### Only extra added code is below ###
    ######################################
    # Create rank
    # Apply ranking within each customer_id based on order_score in descending order
    df['rank'] = df.groupby('SP_ID')['Skill Score'].rank(method='first', ascending=False)
    # Sort the DataFrame by customer_id and rank in ascending order
    df = df.sort_values(by=['SP_ID', 'rank'])
    ######################################


    # Split 'Predicted Cluster' into 'General Cluster' and 'Specific Cluster'
    df[['General Cluster', 'Specific Cluster']] = df['Predicted Cluster'].str.split(' - ', expand=True)

    # Generate the output file path by adding _PROCESSED before the file extension
    file_name, file_extension = os.path.splitext(file_path)
    output_file_path = f"{file_name}_PROCESSED{file_extension}"

    # Save the updated DataFrame back to a new Excel file with _PROCESSED suffix
    df.to_excel(output_file_path, index=False)
    print(f'The Excel file has been updated and saved as "{output_file_path}".')


process_file(predictions_data_path)
# Out:
# The Excel file has been updated and saved as "./TOY_DATA/predictions_data_PROCESSED.xlsx".
