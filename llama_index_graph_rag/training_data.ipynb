# %%
import pandas as pd
import os

# %%
def create_vrf_training_data(vrf_df, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    required_columns = ['Job Title', 'Job Title Generic Description', 'Request Name', 'Request Name Description', 'Skills/Keywords']
    columns = required_columns + ['Add\'l Skills', 'Languages']
    vrf_df = vrf_df.dropna(subset=required_columns)
    vrf_df = vrf_df[columns].fillna("NA")
    vrf_df = vrf_df.apply(lambda x: x.replace("\n", " "))
    vrf_df["Request Id"] = vrf_df["Request Name"].str.split(" - ", n=1).str[1]
    # Make generic training data
    vrf_generic_df = vrf_df[["Job Title", "Job Title Generic Description"]].drop_duplicates(subset=["Job Title", "Job Title Generic Description"])
    vrf_generic_df["summary"] = "The job titled: \"" + vrf_generic_df["Job Title"] + "\" has a description: " + vrf_generic_df["Job Title Generic Description"] + "."
    vrf_generic_df.to_csv(os.path.join(output_dir, "vrf_generic_train_data.csv"), index=False)
    # Make specific training data
    vrf_specific_df = vrf_df[["Request Id"]]
    vrf_specific_df["summary"] = "A specific job request for the job titled: \"" + vrf_df["Job Title"] + "\" has a request id [" + \
        vrf_df["Request Id"] + "] with a specific request description: " + vrf_df["Request Name Description"] + \
        ", and requests the following skills: " + vrf_df["Skills/Keywords"] + ", and " + vrf_df["Add'l Skills"] + \
        " and know the languages: " + vrf_df["Languages"] + "."
    vrf_specific_df.to_csv(os.path.join(output_dir, "vrf_specific_train_data.csv"), index=False)

vrf_df = pd.read_csv('data/vrf_data_new.csv')
create_vrf_training_data(vrf_df, 'data/generated_training_data/')
# Out:
# /var/folders/j6/588zcvgj0sdc9tfsz36sdcp40000gn/T/ipykernel_38359/2315691117.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vrf_specific_df["summary"] = "A specific job request for the job titled: \"" + vrf_df["Job Title"] + "\" has a request id [" + \

# %%
def vrf_single_txt_corpus(specific_train_data_file, generic_train_data_file):
    specific_df = pd.read_csv(specific_train_data_file, header=0)
    generic_df = pd.read_csv(generic_train_data_file, header=0)
    return "\n".join(specific_df["summary"].tolist() + generic_df["summary"].tolist())

corpus = vrf_single_txt_corpus('data/generated_training_data/vrf_specific_train_data.csv', 'data/generated_training_data/vrf_generic_train_data.csv')
print(corpus)

# %%
def create_vrf_single_df(specific_train_data_file, generic_train_data_file):
    specific_df = pd.read_csv(specific_train_data_file, header=0)
    specific_df = specific_df.rename(columns={'Request Id': 'Job Title'})
    generic_df = pd.read_csv(generic_train_data_file, header=0)
    target_columns = ['Job Title', 'summary']
    return pd.concat([specific_df[target_columns], generic_df[target_columns]]).reset_index(drop=True)

df = create_vrf_single_df('data/generated_training_data/vrf_specific_train_data.csv', 'data/generated_training_data/vrf_generic_train_data.csv')
df
# Out:
#                     Job Title  \
# 0       Access Control - 2514
# 1       Access Control - 2515
# 2       Access Control - 2794
# 3       Access Control - 2838
# 4      Account Auditor - 2317
# ..                        ...
# 757  Video calls - Interviews
# 758              Video Editor
# 759     Vietnamese Translator
# 760            Violin Teacher
# 761       Visual Merchandiser
#
#                                                summary
# 0    A specific job request for the job titled: "Ac...
# 1    A specific job request for the job titled: "Ac...
# 2    A specific job request for the job titled: "Ac...
# 3    A specific job request for the job titled: "Ac...
# 4    A specific job request for the job titled: "Ac...
# ..                                                 ...
# 757  The job titled: "Video calls - Interviews" has...
# 758  The job titled: "Video Editor" has a descripti...
# 759  The job titled: "Vietnamese Translator" has a ...
# 760  The job titled: "Violin Teacher" has a descrip...
# 761  The job titled: "Visual Merchandiser" has a de...
#
# [762 rows x 2 columns]

# %%
for i, sentence in enumerate(df["summary"]):
    print(i, sentence)
# Out:
# 0 A specific job request for the job titled: "Access Control" has a request id [Access Control - 2514] with a specific request description: Coordinate Ashram Program check-in at different places and give participants & volunteers program wristband, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 1 A specific job request for the job titled: "Access Control" has a request id [Access Control - 2515] with a specific request description: Program volunteering coordination
# To handle front office and enroll volunteers for program through calls & email, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 2 A specific job request for the job titled: "Access Control" has a request id [Access Control - 2794] with a specific request description: ashram security management, and requests the following skills: Office Assistant / Admin Assistant Others / Army Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Others / CRPF/ BSF IT / Cloud Architect IT / Cyber Security Analyst IT / IT - Others Others / Navy, and NA and know the languages: Tamil English (US) Hindi / हिंदी Albanian / Shqip.
# 3 A specific job request for the job titled: "Access Control" has a request id [Access Control - 2838] with a specific request description: Supporting for access tag issuing, store, Preparing study reports and recommendations - tag / visitors' pass system, infra, security verification, pedestrian and vehicles access, Preparing IT requirements, and requests the following skills: Office Assistant / Admin Assistant IT / IT - Others, and NA and know the languages: English (UK).
# 4 A specific job request for the job titled: "Account Auditor" has a request id [Account Auditor - 2317] with a specific request description: Preparing & Analysing Utilisation reports, and requests the following skills: Accounting / Auditor, and Soft Skills / Articulate in communication IT / Artificial Intelligence/ Machine Learning and know the languages: Tamil English (US).
# 5 A specific job request for the job titled: "Account Auditor" has a request id [Account Auditor - 2506] with a specific request description: Process Auditor - Process Documentation and Audit process of all 24 FPOs, and requests the following skills: Accounting / Auditor, and NA and know the languages: Tamil Kannada.
# 6 A specific job request for the job titled: "Account Auditor" has a request id [Account Auditor - 2887] with a specific request description: Manage complete life cycle of Erp implementation which includes customizations,integration,support understanding of forms,fields and workflow, and requests the following skills: Accounting / Chartered Accountant, and Accounting / Auditor and know the languages: English (US).
# 7 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2276] with a specific request description: Manage complete lifecycle of ERP implementation starts from understanding the business processes of an organization till project management and designing of different phases of ERP implementation which includes - Customizations, integration, support, understanding of forms, fields, workflows etc., and requests the following skills: Accounting / Chartered Accountant, and Accounting / Basic Accountancy and know the languages: English (US).
# 8 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2315] with a specific request description: Preparing & Analysing the reports, and requests the following skills: Soft Skills / Soft-spoken and cordial, and Accounting / Basic Accountancy Basic Computer Skills / Basic Computer (MS Office and Email) Skills and know the languages: Tamil English (US).
# 9 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2316] with a specific request description: Donor Support, and requests the following skills: Soft Skills / Articulate in communication, and Basic Computer Skills / Basic Computer (MS Office and Email) Skills and know the languages: Tamil English (US).
# 10 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2318] with a specific request description: Supporting in technical & admin aspects, and requests the following skills: Accounting / Basic Accountancy, and Environment / Agriculture/ Farmer Basic Computer Skills / Basic Computer (MS Office and Email) Skills and know the languages: English (US) Tamil.
# 11 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2328] with a specific request description: Basic accounting activities, and requests the following skills: Accounting / Basic Accountancy, and NA and know the languages: Tamil.
# 12 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2335] with a specific request description: For back office purpose, and requests the following skills: Accounting / Basic Accountancy Basic Computer Skills / Basic Computer (MS Office and Email) Skills Accounting / Chartered Accountant, and NA and know the languages: NA.
# 13 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2382] with a specific request description: Basic Knowledge Persons-7 Nos, Skilled Persons-3 Nos, and requests the following skills: Accounting / Auditor Corporate / Bank Manager Basic Computer Skills / Basic Computer (MS Office and Email) Skills Accounting / Chartered Accountant Education / Commerce Teacher, and NA and know the languages: Tamil Kannada Telugu / తెలుగు Malayalam.
# 14 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2390] with a specific request description: Background in finance, verification of accounts and bills, and requests the following skills: Accounting / Basic Accountancy Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 15 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2590] with a specific request description: Handling of accounts with various region account in-charges and ashram finance team, and requests the following skills: Accounting / Basic Accountancy, and Basic Computer Skills / Basic Computer (MS Office and Email) Skills and know the languages: NA.
# 16 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2593] with a specific request description: MSR Accounts activity support in Data Entry, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 17 A specific job request for the job titled: "Accountant" has a request id [LSP - Accountant - 2803] with a specific request description: Background in finance, verification of accounts and bills, and requests the following skills: Accounting / Basic Accountancy, and NA and know the languages: NA.
# 18 A specific job request for the job titled: "Accountant" has a request id [Accountant - 2828] with a specific request description: Admin_BLR - Support in processing bills & vouchers, handling queries of inter departments including finance, vendor registration, Fixed Asset
#
# Good communication, MS office (esp. Excel)
#
# Should have worked in accounts, handled bills, basic knowledge about GST, and requests the following skills: Accounting / Basic Accountancy, and NA and know the languages: NA.
# 19 A specific job request for the job titled: "Ad Creative Design Expert" has a request id [Ad Creative Design Expert - 2551] with a specific request description: Analyze existing Ad creatives, give inputs on improving them based on current best practices and framework. Help provide ad creative design suggestions incl. what image should be used, how typography should be used etc for all campaigns, and requests the following skills: Media and Communication / Creative Writer, and NA and know the languages: NA.
# 20 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2254] with a specific request description: Process payroll for employees in the organization
# Familiarize yourself and keep current with the taxation of salaries, benefits and other factors
# Maintain personnel database.
# Manage organization budget and expenses
# Report to department supervisor regarding daily activities and issues
# Address and resolve employee complaints relating to the payroll system
# Work with company database programs to process payroll
# Prepare reports to relevant departments about payroll, company budget and expense, and requests the following skills: Corporate / HR Executive, and Corporate / HR Manager and know the languages: Kannada Tamil Hindi / हिंदी English (UK).
# 21 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2290] with a specific request description: For Courier
# 1. Sorting incoming couriers
# 2. Date Entry of couriers
# 3. Handing over parcels
#
# For Dhvanikarnam Seva (Requesting a new name from Sadhguru) We will be opening it up to all meditators and non meditators within a month
#
# 1. Answer emails
# 2. Help registered participants through their name request journey
# 3. Handle data
# 4. Prepare and courier blessing cards, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial, and NA and know the languages: English (UK) Hindi / हिंदी.
# 22 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2323] with a specific request description: Training and onboardingCreating training courses for the department volunteers, conducting in-person and online training programs
# Back office supportCreating SRT files based on the English transcript and video, request video stem files, maintain the repository of video stems and transcripts/SRT files., and requests the following skills: Soft Skills / Strong Interpersonal skills (Coordinator), and Basic Computer Skills / Basic Computer (MS Office and Email) Skills and know the languages: NA.
# 23 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2331] with a specific request description: Support Sadhguru Academy with creating a repository of knowledge. This will involve consolidating all the Isha leadership content into the SGA system., and requests the following skills: Soft Skills / Articulate in communication, and NA and know the languages: English (UK).
# 24 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2336] with a specific request description: Raising meeting room requests
# Transport / travel requests
# Maintain a expenses logRaising other department requests
# Compiling everyday Log / status snapshots
# Eg EB units / DG units / solar units / no of power interruptions / no of safety related Incidents/ total complaints raised / resolved / meetings / etc, and requests the following skills: Soft Skills / Soft-spoken and cordial, and NA and know the languages: NA.
# 25 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2366] with a specific request description: MHC and Camp Patients Data entry and report generation, and requests the following skills: Basic Computer Skills / Data Entry skills, and NA and know the languages: Tamil English (UK).
# 26 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2367] with a specific request description: Mhc medicine godown support and Camp announcement support, and requests the following skills: General / Inventory, and NA and know the languages: Tamil English (UK).
# 27 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2375] with a specific request description: . Sadhana pada Ateendance Maintenance,meeting arrangements,coordinate with other area coordinators
#
# HP- attendance checking, communicate with HP team,and Dept team
#
#  Email Communication, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Enthusiastic Soft Skills / Fit for Physical Seva, and NA and know the languages: English (US) Tamil.
# 28 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2413] with a specific request description: Administrative Activities (Back Office), and requests the following skills: Soft Skills / Articulate in communication, and NA and know the languages: NA.
# 29 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2438] with a specific request description: Calling, handling email communications, basic computer activities, bookkeeping, data entry, maintaining database, scanning documents, managing inventory, storekeeping, scheduling meetings, organization, time management, and basic report making., and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: English (US) Tamil Hindi / हिंदी.
# 30 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [LSP - Administrative Activities (Back Office) - 2453] with a specific request description: Will be doing back office accounting work, and requests the following skills: Accounting / Basic Accountancy, and NA and know the languages: Tamil.
# 31 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2594] with a specific request description: back office, supervising/monitoring and day to day activities, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: Tamil English (UK).
# 32 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Applications - Administrative Activities (Back Office) - 2631] with a specific request description: Office Assistant, Vouchers, Basic Computer Skills, Excel, and requests the following skills: Office Assistant / Admin Assistant, and NA and know the languages: NA.
# 33 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2650] with a specific request description: we need to document our activity. we are doing variety of activities in the local village so we need documents all those activities, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Basic Computer Skills / Basic Computer (MS Office and Email) Skills and know the languages: Tamil.
# 34 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2651] with a specific request description: Sahaya - meeting scheduling, facilitator and Meet SP team meetings. follow-up with facilitators, ensure feedback is updated. support Step out as needed, and requests the following skills: Basic Computer Skills / Data Entry skills, and Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Enthusiastic Soft Skills / Soft-spoken and cordial and know the languages: Hindi / हिंदी English (US).
# 35 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2680] with a specific request description: Responding to emails and facilitating medical approval through clinic for cottage stay., and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Soft Skills / Articulate in communication and know the languages: NA.
# 36 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2683] with a specific request description: Filing C-forms to the Bureau of Immigration, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 37 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2684] with a specific request description: Overseas guests precheck-in. Gathering information and documents about the guests before their arrival to minimize the check-in process time, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 38 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2685] with a specific request description: Calling, handling email communications, basic computer activities,organization and basic report making., and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Media and Communication / BPO and know the languages: NA.
# 39 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2713] with a specific request description: Programs - Preparing SOP's and also supporting with calling, and requests the following skills: Soft Skills / Soft-spoken and cordial, and Basic Computer Skills / Data Entry skills General / Inventory and know the languages: English (US).
# 40 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2715] with a specific request description: Accommodations - Calling, handling email communications, basic computer activities, bookkeeping, data entry, maintaining database, scanning documents, managing inventory, storekeeping, scheduling meetings, organization, time management, and basic report making., and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Soft Skills / Articulate in communication Soft Skills / Enthusiastic Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: NA.
# 41 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2740] with a specific request description: Overseas Applications - Managing and processing the Emails
# - Managing Data
# - Schedule the interview calls
# - Managing Sadhaka
# - Creating SOPs, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Soft Skills / Articulate in communication Basic Computer Skills / Data Entry skills Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: NA.
# 42 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Tamil Nadu - Administrative Activities (Back Office) - 2743] with a specific request description: - Making followup calls to Schools and colleges. - Higher program enrolments, follow ups with the local potential volunteers. -
# Followup with regional schedulers for Influencer's,
# Scheduling Meeting, taking notes, and action follow ups. -
# Support in planning & organizing the sadhana day, and requests the following skills: Basic Computer Skills / Data Entry skills, and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: NA.
# 43 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Tamil Nadu - Administrative Activities (Back Office) - 2744] with a specific request description: IECO Participants Care (Registration support & 7 session completion reminder giving etc), and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: NA.
# 44 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Tamil Nadu - Administrative Activities (Back Office) - 2745] with a specific request description: Getting the schedule from program coord, managing data, creating reports for analysis, and requests the following skills: Soft Skills / Strong Interpersonal skills (Coordinator), and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial and know the languages: NA.
# 45 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Tamil Nadu - Administrative Activities (Back Office) - 2746] with a specific request description: 1. Fixing and Participating in calls and taking meeting notes
# 2. Following up on the action items with the verticals coord through calls
# 3. Data consolidation vertical wise and region wise for monthly status report
# 4. Organizing support for in person meetings.
# 5. This volunteer can also support MSR back office activities - calls and follow ups., and requests the following skills: Basic Computer Skills / Data Entry skills, and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: NA.
# 46 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Tamil Nadu - Administrative Activities (Back Office) - 2747] with a specific request description: - Creating Registration Forms for regional requirements - Coordinating with the IT team for registration form implementation - Coordinate with the TN region verticals for collating the requirements - Coordinate with the Emedia team for the Content, etc., and requests the following skills: IT / Data Analyst IT / IT - Others, and Soft Skills / Articulate in communication Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: NA.
# 47 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Tamil Nadu - Administrative Activities (Back Office) - 2752] with a specific request description: Free Yoga - Enquiries handling & converting as registration for IE/Hathayoga/Free Yoga, and requests the following skills: Soft Skills / Strong Interpersonal skills (Coordinator), and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial and know the languages: NA.
# 48 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2764] with a specific request description: HP Coordinator
# "* Manage recruitment logistics (Ex: job postings promotion to pre-screening, interview scheduling, etc.)
# * Participate in interview process
# * Coordinate the onboarding of new team members
# * Collate and build onboarding and training modules for all new teachers and staff
# * Manage rotational observation schedules for new teachers
# * Research legally mandated training and create presentations and training materials
# * Track progress of new teachers and provide support as needed
# * Conduct teacher development workshops and events
# * Assist with employee policy development
# * Organize engagement activities and events for team members
# * Manage HP related communication of relevant news, memos, etc.
# * Help with compliance reporting and performance appraisals
# * Coordinate with HP, VCD and OCO on HP related communications", and requests the following skills: Office Assistant / Admin Assistant, and NA and know the languages: NA.
# 49 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2793] with a specific request description: Should have good communication skills and willingness to work beyond normal hours if needed. Should have coordination skills to coordinate with various departments and be a team player., and requests the following skills: Office Assistant / Admin Assistant Soft Skills / Articulate in communication, and NA and know the languages: Tamil English (UK) Hindi / हिंदी.
# 50 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2796] with a specific request description: security back-office work, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: English (US) Tamil.
# 51 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2820] with a specific request description: HP - Completing Joining formalities
# Documentation Verification
# Uploading Documents
#
# Good with excel
# Operating PC
# Good Communication, and requests the following skills: Soft Skills / Strong Interpersonal skills (Coordinator), and NA and know the languages: Kannada Telugu / తెలుగు English (US).
# 52 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2825] with a specific request description: Admin - Interacting with govt Schools/ school children, organizing events, general administrative support
#
# Enthusuiastic, commited, able to follow instruction, school teaching experience a plus, and requests the following skills: Office Assistant / Admin Assistant, and NA and know the languages: English (US) Kannada.
# 53 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2831] with a specific request description: VRO - Welcome point
#
# front office/ backend calling, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 54 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2836] with a specific request description: 1. Call applicants and support with arranging for interview dates and times
# 2. Ensure support from when their interview is fixed till the interview is complete i.e answer any questions they have, support in walking them through cottage booking process, ensure welcome point is aware of their arrival, meet them at arrival, ensure wrist band collection
# 3. Ensure set up for video and interview
# 4. Answer any queries they may have after the interview, and requests the following skills: Office Assistant / Admin Assistant Soft Skills / Articulate in communication, and NA and know the languages: English (UK) Hindi / हिंदी Tamil.
# 55 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2844] with a specific request description: Nature of our activity involves sensitive information. We need someone with more maturity, willing and aspiring for Poornanga., and requests the following skills: Soft Skills / Soft-spoken and cordial, and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Enthusiastic and know the languages: NA.
# 56 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2846] with a specific request description: VCD - Bringing Poornangas. Backend data/ making calls, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Soft Skills / Articulate in communication and know the languages: NA.
# 57 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2856] with a specific request description: Security & Parking - Security Backoffice. Backoffice work, and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and NA and know the languages: NA.
# 58 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2864] with a specific request description: Seva., and requests the following skills: Basic Computer Skills / Basic Computer (MS Office and Email) Skills, and Soft Skills / Articulate in communication Soft Skills / Enthusiastic and know the languages: NA.
# 59 A specific job request for the job titled: "Administrative Activities (Back Office)" has a request id [Administrative Activities (Back Office) - 2875] with a specific request description: IPC MSR Back Office -
#
# 3 volunteers for "1. Fixing and Participating in calls and taking meeting notes
# 2. Following up on the action items with the verticals coord through calls"
#
# 1 volunteer for "Enquiries handling & converting as registration for IE/Hathayoga/Free Yoga", and requests the following skills: Basic Computer Skills / Data Entry skills, and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: NA.
# 60 A specific job request for the job titled: "Agri Marketing" has a request id [Agri Marketing - 2488] with a specific request description: Explore crop wise market, value added products
# Establish market linkages. Business Plan preparation and daily tracking the plan vs actual., and requests the following skills: Corporate / Marketing & Branding Manager, and Environment / Agriculture/ Farmer and know the languages: Tamil English (UK).
# 61 A specific job request for the job titled: "Akshaya Volunteers" has a request id [Akshaya Volunteers - 2735] with a specific request description: To support in multiple areas in Akshaya., and requests the following skills: Soft Skills / Fit for Physical Seva, and NA and know the languages: NA.
# 62 A specific job request for the job titled: "Allopathy Doctor" has a request id [Allopathy Doctor - 2392] with a specific request description: Allopathy Doctor, and requests the following skills: Medical / Allopathy Doctor, and NA and know the languages: NA.
# 63 A specific job request for the job titled: "Allopathy Doctor" has a request id [Allopathy Doctor - 2393] with a specific request description: Ayurveda Doctor. But this category is not available in the job title, so raising under Allopathy Doctor, and requests the following skills: Medical / Allopathy Doctor, and NA and know the languages: NA.
# 64 A specific job request for the job titled: "Allopathy Doctor" has a request id [Allopathy Doctor - 2435] with a specific request description: To assess the patients diagnose and treat them accordingly, and requests the following skills: Medical / Allopathy Doctor, and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills and know the languages: English (UK) Tamil Hindi / हिंदी.
# 65 A specific job request for the job titled: "Allopathy Doctor" has a request id [Allopathy Doctor - 2447] with a specific request description: Need Doctors for the Muttathuvayal Tribal Clinic, and requests the following skills: Medical / Allopathy Doctor, and Soft Skills / Fit for Physical Seva and know the languages: Tamil English (US).
# 66 A specific job request for the job titled: "Allopathy Doctor" has a request id [Allopathy Doctor - 2622] with a specific request description: Pediatrician
# MBBS and Specialization in Pedeatrics, and requests the following skills: Medical / Allopathy Doctor, and NA and know the languages: NA.
# 67 A specific job request for the job titled: "Allopathy Doctor" has a request id [Allopathy Doctor - 2703] with a specific request description: Health - Allopathy Doctor, To assess participant health situation, and requests the following skills: Medical / Allopathy Doctor, and Medical / Nurse Medical / Pharmacist Medical / Physiotherapist and know the languages: NA.
# 68 A specific job request for the job titled: "Arabic Translator" has a request id [Arabic Translator - 2250] with a specific request description: 1 support coordinator: Assigns tasks to volunteers and makes sure that all the tasks are completed on time.
# 1 trasnlator: Translation of text, creatives (text+image) and videos.
# 1 Proofreader: Final review of the translated text to correct distorions in translation, grammar mistakes and to maintain the consistency of translation style across all translations withing a given language
# 1 video editor : Video editing in DaVinci resolve: stictching audio track to the English video, adding subtitles, supers and slides, and requests the following skills: Soft Skills / Articulate in communication, and Basic Computer Skills / Data Entry skills Media and Communication / Editor and know the languages: Arabic / الْعَرَبيّة.
# 69 A specific job request for the job titled: "Architect" has a request id [LSP - Architect - 2454] with a specific request description: Architectural Drawings for Multi-Storied building and Independent houses.
# Would be good to have some exposure to MEP design
# Should know to use Sketchup or AutoCad
# May work on Interior designs, and requests the following skills: Construction & Fabrication / Architect, and NA and know the languages: Tamil.
# 70 A specific job request for the job titled: "Architect" has a request id [Architect - 2874] with a specific request description: IPC MSR - helping in drawing with MSR should knw CAD skech up, Adobe illustrator, and requests the following skills: Soft Skills / Strong Interpersonal skills (Coordinator), and Soft Skills / Articulate in communication Basic Computer Skills / Basic Computer (MS Office and Email) Skills Soft Skills / Soft-spoken and cordial and know the languages: NA.
# 71 A specific job request for the job titled: "Art Teacher" has a request id [Art Teacher - 2570] with a specific request description: supporting the teacher in the art class in small groups, and requests the following skills: Education / Arts and Crafts Teacher, and NA and know the languages: English (UK).
# 72 A specific job request for the job titled: "Art Teacher" has a request id [Art Teacher - 2843] with a specific request description: Taking care of Decorative , Aesthetic and creative part of events at ashram
#
# Qualities
# Exceptional skill at crafting
# Creativity
# Painting
# Cultural competence, and requests the following skills: Arts and Crafts / Actor, and Education / Arts and Crafts Teacher and know the languages: English (UK).
# 73 A specific job request for the job titled: "Artificial Intelligence (AI) Enthusiast" has a request id [Artificial Intelligence (AI) Enthusiast - 2391] with a specific request description: Build and train AI & Machine Learning models after analyzing data in the form of existing publications documents; formatting and clustering them. Look at existing activities in dept and see where automation can be introduced to reduce workload., and requests the following skills: IT / Artificial Intelligence/ Machine Learning IT / Developer IT / Developer - front end IT / IT / Developer IT / Python Developer, and NA and know the languages: NA.
# 74 A specific job request for the job titled: "Artificial Intelligence (AI) Enthusiast" has a request id [Artificial Intelligence (AI) Enthusiast - 2409] with a specific request description: Researching and staying updated on the latest advancements in AI technologies, particularly in the realm of creative applications.
#
# Experimenting with machine learning algorithms, neural networks, and other AI techniques to generate innovative outputs in various creative domains such as art and design
#
# Collaborating with cross-functional teams, including designers, developers, and researchers, to integrate AI solutions into creative projects and workflows.
#
# Developing and prototyping AI-driven tools, applications, or algorithms that enhance the creative process and push the boundaries of what is possible in creative expression., and requests the following skills: IT / Artificial Intelligence/ Machine Learning, and NA and know the languages: English (UK).
# 75 A specific job request for the job titled: "Artificial Intelligence (AI) Enthusiast" has a request id [Applications - Artificial Intelligence (AI) Enthusiast - 2617] with a specific request description: AI, Machine Learning, NLP, Deep Learning,, and requests the following skills: IT / Artificial Intelligence/ Machine Learning, and NA and know the languages: NA.
# 76 A specific job request for the job titled: "Artificial Intelligence (AI) Enthusiast" has a request id [Artificial Intelligence (AI) Enthusiast - 2654] with a specific request description: Sahaya - looking at all Sahaya operations and workflows. seeing how to automate and simplify processes, come up with IT-based solutions if needed, AppSheet, scripts etc. seeing how to smoothen operations with other teams, if needed also training them on how to do it or supporting in creating automations for them. create/work on Sahaya SOPs, and requests the following skills: IT / Devops Engineer Corporate / Operations Manager, and Soft Skills / Enthusiastic and know the languages: English (US).
# 77 A specific job request for the job titled: "Artificial Intelligence (AI) Enthusiast" has a request id [Marketing - Artificial Intelligence (AI) Enthusiast - 2722] with a specific request description: Need AI market expertise for Chatbot Integration for Customer Support, and requests the following skills: IT / Artificial Intelligence/ Machine Learning IT / ERP Consultant, and IT / IT Project Manager and know the languages: NA.
# 78 A specific job request for the job titled: "Artificial Intelligence (AI) Enthusiast" has a request id [Artificial Intelligence (AI) Enthusiast - 2785] with a specific request description: He will be doing research on different tools & different use cases for our sub-teams to see where AI products can help solve our problems, and requests the following skills: IT / Artificial Intelligence/ Machine Learning, and NA and know the languages: NA.
# 79 A specific job request for the job titled: "Artificial Intelligence (AI) Enthusiast" has a request id [Infrastructure - Artificial Intelligence (AI) Enthusiast - 2800] with a specific request description: Coding experience on Powershell, bash and Python scripting. Creating and scheduling batch files. Knowledge on Active Directory (AD), Servers, Networking and Identity Access Management (IAM)., and requests the following skills: IT / Artificial Intelligence/ Machine Learning, and IT / Developer and know the languages: NA.
# 80 A specific job request for the job titled: "Ashram Support" has a request id [Ashram Support - 2787] with a specific request description: Ashram Support volunteers, and requests the following skills: Soft Skills / Fit for Physical Seva, and NA and know the languages: NA.
# 81 A specific job request for the job titled: "Ashram Tour Guide" has a request id [Ashram Tour Guide - 2832] with a specific request description: Enhancement of guest experience.
#
#  ORIENTATION to be conducted in batches and GUIDED TOUR of cottage guests regularly
#
# QUALITIES
# Good communication,Coordination ,Enthusiastic,
# Engaging..
# Communicative. ...
# Outgoing. ...
# Funny. ...
# Decisive. ...
# Organised. ...
# Punctual., and requests the following skills: Soft Skills / Articulate in communication, and Soft Skills / Strong Interpersonal skills (Coordinator) and know the languages: English (UK) Tamil Hindi / हिंदी.
# 82 A specific job request for the job titled: "Assamese Translator" has a request id [Assamese Translator - 2426] with a specific request description: Translation of Sadhguru videos, articles, and books., and requests the following skills: Media and Communication / Copywriter, and NA and know the languages: English (UK) Assamese.
# 83 A specific job request for the job titled: "Asset and Inventory management" has a request id [Asset and Inventory management - 2311] with a specific request description: 1. Managing inventory levels to meet project and maintenance requirements.
# 2. Optimizing inventory processes, including ordering, receiving, and storage., and requests the following skills: General / Inventory, and Soft Skills / Fit for Physical Seva and know the languages: English (US) Tamil.
# 84 A specific job request for the job titled: "Asset and Inventory management" has a request id [Asset and Inventory management - 2312] with a specific request description: 1. Managing inventory levels to meet project and maintenance requirements.
# 2. Optimizing inventory processes, including ordering, receiving, and storage., and requests the following skills: General / Inventory, and Soft Skills / Fit for Physical Seva and know the languages: English (US) Tamil.
# 85 A specific job request for the job titled: "Asset and Inventory management" has a request id [Asset and Inventory management - 2813] with a specific request description: Amenities - Purchase and Inventory Coordinator, and requests the following skills: General / Inventory, and NA and know the languages: NA.
# 86 A specific job request for the job titled: "Asset and Inventory management" has a request id [Asset and Inventory management - 2827] with a specific request description: Purchases_BLR -
#
# Supporting in bringing the materials from the vendor place, can converse with the vendor in a humble manner so good rapport can be developed between vendor & ishaGood communication, Enthusiastic in field work
#
# Purchase store handling -receiving of purchased materials, sorting & issuing to the user department
#
# Should have handled stores, but it is not compulsory
#
# To support in purchases on behalf of our SSB departments by handling new product / variant creation, obtaining purpose code, support in timely raising of PRs
#
# Good communication, computer & software/app handling, and requests the following skills: General / Inventory, and NA and know the languages: English (US) Kannada.
# 87 A specific job request for the job titled: "Asset and Inventory management" has a request id [Asset and Inventory management - 2845] with a specific request description: Temple Production - The Volunteer would take care of a Store & support with Sadhguru Sannidhi maintainance of the Ashram., and requests the following skills: General / Inventory, and Basic Computer Skills / Basic Computer (MS Office and Email) Skills Basic Computer Skills / Data Entry skills and know the languages: NA.
# 88 A specific job request for the job titled: "Asset and Inventory management" has a request id [Asset and Inventory management - 2850] with a specific request description: Electrical Store - 1. Store Data Entry
# 2. Managing inventory levels to meet project and maintenance requirements.
# 3. Optimizing inventory processes, including ordering, receiving, and storage., and requests the following skills: General / Inventory, and NA and know the languages: NA.
# 89 A specific job request for the job titled: "Audio calls - Interviews" has a request id [Audio calls - Interviews - 2400] with a specific request description: To call patients for the treatment review, program participants for feedback, and requests the following skills: Media and Communication / BPO, and NA and know the languages: NA.
# 90 A specific job request for the job titled: "Audio calls - Interviews" has a request id [Audio calls - Interviews - 2736] with a specific request description: Indian Applications - To collect or verify detailed information on an audio call. They should be open to talking at length and not be of a shy demeanor., and requests the following skills: Soft Skills / Articulate in communication, and Media and Communication / Communication Trainer Soft Skills / Enthusiastic Soft Skills / Soft-spoken and cordial and know the languages: NA.
# 91 A specific job request for the job titled: "Audio calls - Interviews" has a request id [Audio calls - Interviews - 2737] with a specific request description: Indian Applications - Satsang ishanga to attend to practice corrections of applicants on a regular basis, and requests the following skills: Soft Skills / Articulate in communication Soft Skills / Enthusiastic Soft Skills / Soft-spoken and cordial Soft Skills / Strong Interpersonal skills (Coordinator), and NA and know the languages: NA.
# 92 A specific job request for the job titled: "Bengali Translator" has a request id [Bengali Translator - 2422] with a specific request description: Translation of Sadhguru videos, articles, and books., and requests the following skills: Media and Communication / Copywriter, and NA and know the languages: English (UK) Bengali / বাংলা.
# 93 A specific job request for the job titled: "Biology Teacher" has a request id [IHS - Biology Teacher - 2606] with a specific request description: "* Plan lessons and develop curricula aligned to the prescribed syllabus
# * Plan and conduct laboratory experiments and investigations to help students develop experimental skills, understand scientific principles, and apply theoretical concepts in practical contexts.
# * Provide clear explanations, examples, and demonstrations to help students grasp complex biological concepts and principles and make connections between theory and real-world applications.
# * Differentiate instruction to accommodate the diverse learning needs, interests, and abilities of students, including those with special needs
# * Utilize technology and digital resources, such as simulations, interactive multimedia, and online resources, to enhance instruction, engage students, and facilitate learning.
# * Assess student learning and progress through a variety of formative and summative assessments, including quizzes, tests, laboratory reports, projects, and performance tasks.
# * Provide timely and constructive feedback to students to help them understand their strengths and areas for improvement and guide their academic growth and development.
# * Maintain accurate, thorough, and diversified records of student progress
# * Participate in team meetings, workshops, and other learning opportunities
# * Perform miscellaneous job-related duties as assigned, and requests the following skills: Education / Biology Teacher, and NA and know the languages: NA.
# 94 A specific job request for the job titled: "Business Analyst (BA)" has a request id [Business Analyst (BA) - 2403] with a specific request description: Need to test the current software and Fulfill Department IT requirements., and requests the following skills: IT / Business Analyst, and IT / Business Analyst IT / Developer IT / UX Designer and know the languages: NA.
# ...
# 725 The job titled: "Romanian Video Editor" has a description: Edit and create video content in Romanian, ensuring high-quality visuals, sound, and narrative flow. Responsibilities include cutting, mixing, and enhancing video footage while maintaining linguistic and cultural accuracy. Requires proficiency in video editing software, strong attention to detail, and fluency in both Romanian and the target language..
# 726 The job titled: "Russian Video Editor" has a description: Edit and create video content in Russian, ensuring seamless integration of visuals, audio, and narrative. Responsibilities include cutting, enhancing, and mixing footage, while maintaining linguistic and cultural accuracy. Requires proficiency in video editing software, strong attention to detail, and fluency in Russian and the target language..
# 727 The job titled: "Safety Professionals" has a description: Ensure the health, safety, and well-being of employees and the workplace by identifying hazards, conducting risk assessments, and implementing safety protocols. Monitor compliance with safety regulations and provide training on safe work practices. Requires knowledge of safety standards, attention to detail, and the ability to manage emergency situations effectively..
# 728 The job titled: "Sales Manager/ Executive" has a description: Oversee and drive sales activities to meet organizational goals. Responsibilities include identifying prospects, managing customer relationships, negotiating deals, and ensuring target achievements. Requires strong communication, negotiation skills, and the ability to analyze market trends. Experience in sales strategies and team collaboration is essential..
# 729 The job titled: "Sanskrit Teacher" has a description: Teach and promote the study of Sanskrit, including grammar, literature, and cultural context. Responsibilities include preparing lesson plans, conducting classes, and fostering an understanding of the language's significance. Requires expertise in Sanskrit, excellent communication skills, and a passion for teaching and preserving cultural heritage..
# 730 The job titled: "Server Engineer" has a description: Manage and maintain servers, ensuring their optimal performance, security, and uptime. Responsibilities include installing, configuring, troubleshooting, and upgrading server hardware and software. Requires expertise in server management, network protocols, and troubleshooting, along with the ability to handle server-related issues efficiently to support business operations..
# 731 The job titled: "Session Designer" has a description: Design and develop engaging and informative sessions for training, workshops, or educational programs. Responsibilities include creating content, structuring sessions, and incorporating interactive elements to enhance learning experiences. Requires strong communication, creativity, and instructional design skills to ensure the sessions meet the learning objectives and audience needs..
# 732 The job titled: "Session Facilitator" has a description: Guide and manage group sessions, ensuring smooth interactions, active participation, and achievement of session goals. Responsibilities include leading discussions, providing support, and fostering an engaging learning environment. Requires strong communication, interpersonal skills, and the ability to manage group dynamics while encouraging collaboration and knowledge sharing..
# 733 The job titled: "Singers / Instrumentalists / Musicians" has a description: Perform and create music through vocals or instruments, delivering high-quality performances for audiences or recordings. Responsibilities include rehearsing, collaborating with other musicians, and performing at events or in studio settings. Requires musical talent, proficiency in an instrument or voice, and a passion for creating and sharing music..
# 734 The job titled: "Site Supervisor" has a description: Oversee and manage daily operations on construction or project sites, ensuring safety, quality, and adherence to timelines. Responsibilities include supervising workers, coordinating with contractors, inspecting site conditions, and ensuring compliance with safety regulations. Requires strong leadership, organizational skills, and knowledge of construction practices and regulations..
# 735 The job titled: "Social media Manager" has a description: Manage and execute social media strategies to increase brand awareness and engagement. Responsibilities include creating content, scheduling posts, analyzing metrics, and engaging with followers. Requires strong communication skills, creativity, and knowledge of social media platforms and trends to effectively build and maintain an online presence..
# 736 The job titled: "Spanish Translator" has a description: Translate written or spoken content between Spanish and other languages, ensuring accuracy and cultural relevance. Responsibilities include translating documents, interpreting conversations, and localizing materials. Requires fluency in Spanish, strong writing and comprehension skills, and a deep understanding of cultural nuances for context-appropriate translations..
# 737 The job titled: "Stay Area Support" has a description: Provide assistance and support to individuals in stay areas, ensuring a comfortable and safe environment. Responsibilities include managing accommodations, addressing concerns, coordinating logistics, and ensuring all facilities meet requirements. Requires strong organizational, communication, and problem-solving skills to handle guest needs and maintain smooth operations..
# 738 The job titled: "Structural Engineer" has a description: Design, analyze, and oversee the construction of structural components for buildings, bridges, and other infrastructure projects. Responsibilities include ensuring safety, stability, and compliance with regulations, conducting material tests, and collaborating with architects and contractors. Requires strong knowledge of engineering principles, materials, and structural design software..
# 739 The job titled: "Supervising Activities" has a description: Oversee and manage daily activities, ensuring they align with organizational goals and standards. Responsibilities include coordinating tasks, monitoring progress, providing guidance, and ensuring safety and efficiency. Requires strong leadership, problem-solving, and communication skills to ensure activities are completed on time and within scope..
# 740 The job titled: "Swimming coach" has a description: Train and mentor swimmers of all skill levels, improving technique, endurance, and performance. Responsibilities include developing training plans, providing feedback, and conducting individual or group lessons. Requires deep knowledge of swimming techniques, strong communication skills, and the ability to motivate and guide athletes towards achieving their goals..
# 741 The job titled: "Tabla Teacher" has a description: Teach and promote the art of playing the tabla, including rhythm patterns, techniques, and cultural significance. Responsibilities include preparing lesson plans, conducting classes, and offering individualized feedback. Requires expertise in tabla performance, strong communication skills, and a passion for teaching music and preserving cultural traditions..
# 742 The job titled: "Tamil Teacher" has a description: Teach the Tamil language, including grammar, literature, and cultural context. Responsibilities include preparing lesson plans, conducting classes, and fostering a deep understanding of the language's nuances. Requires fluency in Tamil, strong communication skills, and a passion for teaching and preserving cultural heritage..
# 743 The job titled: "Tamil Translator" has a description: Translate written or spoken content between Tamil and other languages, ensuring accuracy and cultural relevance. Responsibilities include translating documents, interpreting conversations, and localizing materials. Requires fluency in Tamil, strong writing and comprehension skills, and an understanding of cultural nuances to deliver precise and context-appropriate translations..
# 744 The job titled: "Teacher - Others" has a description: Teach various subjects or skills not covered under specific teaching roles. Responsibilities include preparing lesson plans, delivering instructional content, and assessing student progress. Requires strong communication, organizational skills, and the ability to adapt teaching methods to meet diverse learner needs in a variety of subjects or disciplines..
# 745 The job titled: "Technical Support" has a description: Provide assistance and troubleshooting for technical issues related to software, hardware, or systems. Responsibilities include diagnosing problems, guiding users through solutions, and offering support via phone, email, or in-person. Requires strong problem-solving skills, technical knowledge, and the ability to communicate effectively with users to resolve issues efficiently..
# 746 The job titled: "Technical support for Audio" has a description: Provide technical assistance for audio-related issues, including equipment setup, troubleshooting, and maintenance. Responsibilities include diagnosing audio problems, configuring sound systems, and ensuring optimal performance for events or recordings. Requires expertise in audio equipment, signal processing, and strong problem-solving skills to deliver effective support in real-time situations..
# 747 The job titled: "Telugu Translator" has a description: Translate written or spoken content between Telugu and other languages, ensuring accuracy and cultural relevance. Responsibilities include translating documents, interpreting conversations, and localizing materials. Requires fluency in Telugu, strong writing and comprehension skills, and an understanding of cultural nuances to deliver precise and context-appropriate translations..
# 748 The job titled: "Tennis coach" has a description: Teach and train individuals or teams in tennis, improving skills, techniques, and overall performance. Responsibilities include developing training plans, providing feedback, and conducting drills. Requires expertise in tennis strategies, strong communication skills, and the ability to motivate and guide players at various skill levels to achieve their goals..
# 749 The job titled: "Test Engineer" has a description: Design, execute, and evaluate software or hardware tests to ensure products meet quality standards. Responsibilities include creating test plans, identifying bugs, and documenting results. Requires strong problem-solving skills, attention to detail, and proficiency in testing tools and methodologies to ensure functionality, performance, and reliability of the product..
# 750 The job titled: "Thai Translator" has a description: Translate written or spoken content between Thai and other languages, ensuring accuracy and cultural relevance. Responsibilities include translating documents, interpreting conversations, and localizing materials. Requires fluency in Thai, strong writing and comprehension skills, and an understanding of cultural nuances to deliver precise and context-appropriate translations..
# 751 The job titled: "Traditional Chinese Video Editor" has a description: Edit and create video content in Traditional Chinese, ensuring high-quality visuals, sound, and narrative flow. Responsibilities include cutting, mixing, and enhancing footage, while maintaining linguistic and cultural accuracy. Requires proficiency in video editing software, strong attention to detail, and fluency in Traditional Chinese and the target language..
# 752 The job titled: "Transcription" has a description: Convert audio or video recordings into written text, ensuring accuracy and clarity. Responsibilities include listening carefully, transcribing spoken words, and formatting the text according to requirements. Requires strong listening, typing, and language skills, with attention to detail and the ability to handle various accents and audio quality..
# 753 The job titled: "Translators" has a description: Translate written or spoken content between languages, ensuring accuracy, clarity, and cultural relevance. Responsibilities include translating documents, interpreting conversations, and localizing materials to suit the target audience. Requires fluency in at least two languages, strong writing and comprehension skills, and a deep understanding of cultural nuances..
# 754 The job titled: "UI Designer" has a description: Design and create visually appealing and user-friendly interfaces for websites, apps, or software. Responsibilities include developing design concepts, wireframes, and prototypes, ensuring a seamless user experience. Requires strong knowledge of design principles, proficiency in design tools, and the ability to collaborate with developers to implement designs effectively..
# 755 The job titled: "UX Desinger" has a description: Design user-centered experiences for websites, apps, or products by researching user needs and behaviors. Responsibilities include creating wireframes, prototypes, and conducting usability testing. Requires strong skills in user research, interaction design, and problem-solving, with a focus on enhancing the overall user experience and ensuring accessibility and functionality..
# 756 The job titled: "Veterinary Doctor" has a description: Diagnose and treat medical conditions in animals, providing preventative care and surgical interventions. Responsibilities include examining pets or livestock, administering vaccines, prescribing medications, and performing surgeries. Requires a degree in veterinary medicine, strong medical knowledge, and the ability to care for various animal species with compassion and expertise..
# 757 The job titled: "Video calls - Interviews" has a description: Conduct remote job interviews via video calls to assess candidates' qualifications, skills, and fit for the role. Responsibilities include scheduling interviews, evaluating candidates, and providing feedback. Requires strong communication skills, familiarity with video conferencing tools, and the ability to maintain professionalism during remote interactions..
# 758 The job titled: "Video Editor" has a description: Edit and assemble video footage to create high-quality content for various platforms. Responsibilities include cutting, enhancing, and combining visuals, audio, and effects to deliver a polished final product. Requires proficiency in video editing software, strong attention to detail, and creativity in storytelling through visual media..
# 759 The job titled: "Vietnamese Translator" has a description: Translate written or spoken content between Vietnamese and other languages, ensuring accuracy and cultural relevance. Responsibilities include translating documents, interpreting conversations, and localizing materials. Requires fluency in Vietnamese, strong writing and comprehension skills, and an understanding of cultural nuances for precise and context-appropriate translations..
# 760 The job titled: "Violin Teacher" has a description: Teach students how to play the violin, focusing on technique, music theory, and performance skills. Responsibilities include preparing lesson plans, conducting individual or group lessons, and providing constructive feedback. Requires proficiency in violin playing, strong communication skills, and a passion for teaching and nurturing musical talent..
# 761 The job titled: "Visual Merchandiser" has a description: Design and implement visually appealing layouts and graphics for a website to enhance user experience and brand representation. Responsibilities include arranging content, optimizing images, and creating engaging visuals that align with the brand's aesthetics. Requires creativity, design skills, and knowledge of web trends and user interface principles..

# %%
df['Job Title'].to_list()
# Out:
# ['Access Control - 2514',
#  'Access Control - 2515',
#  'Access Control - 2794',
#  'Access Control - 2838',
#  'Account Auditor - 2317',
#  'Account Auditor - 2506',
#  'Account Auditor - 2887',
#  'Accountant - 2276',
#  'Accountant - 2315',
#  'Accountant - 2316',
#  'Accountant - 2318',
#  'Accountant - 2328',
#  'Accountant - 2335',
#  'Accountant - 2382',
#  'Accountant - 2390',
#  'Accountant - 2590',
#  'Accountant - 2593',
#  'LSP - Accountant - 2803',
#  'Accountant - 2828',
#  'Ad Creative Design Expert - 2551',
#  'Administrative Activities (Back Office) - 2254',
#  'Administrative Activities (Back Office) - 2290',
#  'Administrative Activities (Back Office) - 2323',
#  'Administrative Activities (Back Office) - 2331',
#  'Administrative Activities (Back Office) - 2336',
#  'Administrative Activities (Back Office) - 2366',
#  'Administrative Activities (Back Office) - 2367',
#  'Administrative Activities (Back Office) - 2375',
#  'Administrative Activities (Back Office) - 2413',
#  'Administrative Activities (Back Office) - 2438',
#  'LSP - Administrative Activities (Back Office) - 2453',
#  'Administrative Activities (Back Office) - 2594',
#  'Applications - Administrative Activities (Back Office) - 2631',
#  'Administrative Activities (Back Office) - 2650',
#  'Administrative Activities (Back Office) - 2651',
#  'Administrative Activities (Back Office) - 2680',
#  'Administrative Activities (Back Office) - 2683',
#  'Administrative Activities (Back Office) - 2684',
#  'Administrative Activities (Back Office) - 2685',
#  'Administrative Activities (Back Office) - 2713',
#  'Administrative Activities (Back Office) - 2715',
#  'Administrative Activities (Back Office) - 2740',
#  'Tamil Nadu - Administrative Activities (Back Office) - 2743',
#  'Tamil Nadu - Administrative Activities (Back Office) - 2744',
#  'Tamil Nadu - Administrative Activities (Back Office) - 2745',
#  'Tamil Nadu - Administrative Activities (Back Office) - 2746',
#  'Tamil Nadu - Administrative Activities (Back Office) - 2747',
#  'Tamil Nadu - Administrative Activities (Back Office) - 2752',
#  'Administrative Activities (Back Office) - 2764',
#  'Administrative Activities (Back Office) - 2793',
#  'Administrative Activities (Back Office) - 2796',
#  'Administrative Activities (Back Office) - 2820',
#  'Administrative Activities (Back Office) - 2825',
#  'Administrative Activities (Back Office) - 2831',
#  'Administrative Activities (Back Office) - 2836',
#  'Administrative Activities (Back Office) - 2844',
#  'Administrative Activities (Back Office) - 2846',
#  'Administrative Activities (Back Office) - 2856',
#  'Administrative Activities (Back Office) - 2864',
#  'Administrative Activities (Back Office) - 2875',
#  'Agri Marketing - 2488',
#  'Akshaya Volunteers - 2735',
#  'Allopathy Doctor - 2392',
#  'Allopathy Doctor - 2393',
#  'Allopathy Doctor - 2435',
#  'Allopathy Doctor - 2447',
#  'Allopathy Doctor - 2622',
#  'Allopathy Doctor - 2703',
#  'Arabic Translator - 2250',
#  'LSP - Architect - 2454',
#  'Architect - 2874',
#  'Art Teacher - 2570',
#  'Art Teacher - 2843',
#  'Artificial Intelligence (AI) Enthusiast - 2391',
#  'Artificial Intelligence (AI) Enthusiast - 2409',
#  'Applications - Artificial Intelligence (AI) Enthusiast - 2617',
#  'Artificial Intelligence (AI) Enthusiast - 2654',
#  'Marketing - Artificial Intelligence (AI) Enthusiast - 2722',
#  'Artificial Intelligence (AI) Enthusiast - 2785',
#  'Infrastructure - Artificial Intelligence (AI) Enthusiast - 2800',
#  'Ashram Support - 2787',
#  'Ashram Tour Guide - 2832',
#  'Assamese Translator - 2426',
#  'Asset and Inventory management - 2311',
#  'Asset and Inventory management - 2312',
#  'Asset and Inventory management - 2813',
#  'Asset and Inventory management - 2827',
#  'Asset and Inventory management - 2845',
#  'Asset and Inventory management - 2850',
#  'Audio calls - Interviews - 2400',
#  'Audio calls - Interviews - 2736',
#  'Audio calls - Interviews - 2737',
#  'Bengali Translator - 2422',
#  'IHS - Biology Teacher - 2606',
#  'Business Analyst (BA) - 2403',
#  'Business Analyst (BA) - 2469',
#  'Business Analyst (BA) - 2583',
#  'Applications - Business Analyst (BA) - 2613',
#  'Business Analyst (BA) - 2687',
#  'Business Analyst (BA) - 2710',
#  'Marketing - Business Analyst (BA) - 2731',
#  'Business Analyst (BA) - 2841',
#  'Business Analyst (BA) - 2863',
#  'CAD Designer - 2303',
#  'CAD Designer - 2304',
#  'CAD Designer - 2327',
#  'Call Centre - 2269',
#  'Call Centre - 2334',
#  'Call Centre - 2378',
#  'Call Centre - 2444',
#  'Call Centre - 2707',
#  'Call Centre - 2714',
#  'Carnatic Music Teacher - 2355',
#  'Carnatic Music Teacher - 2630',
#  'Chartered Accountant - 2330',
#  'Chartered Accountant - 2499',
#  'Chartered Accountant - 2865',
#  'LSP - Chemical/ Paint Engineer - 2462',
#  'LSP - Civil Estimators - 2458',
#  'Civil Estimators - 2859',
#  'Class Teacher - Junior School - 2325',
#  'Class Teacher - Middle School - 2569',
#  'Class Teacher - Middle School - 2601',
#  'Company Secretary - 2502',
#  'Company Secretary - 2790',
#  'Compliance Lawyer - 2791',
#  'Computer Teacher - 2870',
#  'Content Creator - 2493',
#  'Content Creator - 2503',
#  'Content Creator - 2541',
#  'Content Creator - 2579',
#  'Content Creator - 2810',
#  'Content Manager - 2285',
#  'Content Manager - 2446',
#  'Content Manager - 2668',
#  'Content Manager - 2691',
#  'Tamil Nadu - Content Manager - 2755',
#  'Content Manager - 2888',
#  'Content Researcher - 2298',
#  'Content Researcher - 2416',
#  'Content Researcher - 2542',
#  'Content Researcher - 2669',
#  'Content Researcher - Tamil - 2571',
#  'Content Strategist - 2525',
#  'Content Strategist - 2526',
#  'Content Strategist - 2540',
#  'Content Strategist - 2584',
#  'Content Strategist - 2671',
#  'Content Support - 2670',
#  'Content Support - 2689',
#  'Marketing - Content Support - 2726',
#  'Content Support Executive (CSE) - 2286',
#  'Content Writer - 2287',
#  'Content Writer - 2388',
#  'Content Writer - 2450',
#  'Content Writer - 2544',
#  'Content Writer - 2547',
#  'Content Writer - 2550',
#  'Content Writer - 2582',
#  'Content Writer - 2661',
#  'Content Writer - 2694',
#  'Marketing - Content Writer - 2725',
#  'Content Writer - 2738',
#  'Content Writer - 2869',
#  'Content Writer - 2882',
#  'Content Writer - Media - 2292',
#  'Content Writer - Media - 2358',
#  'Contracts Lawyer - 2772',
#  'Conversion Rate Expert - 2365',
#  'Coordinating Activities - 2257',
#  'Coordinating Activities - 2299',
#  'Coordinating Activities - 2314',
#  'Coordinating Activities - 2377',
#  'Coordinating Activities - 2385',
#  'Coordinating Activities - 2386',
#  'Coordinating Activities - 2399',
#  'Coordinating Activities - 2491',
#  'Coordinating Activities - 2567',
#  'Coordinating Activities - 2572',
#  'Coordinating Activities - 2655',
#  'Coordinating Activities - 2672',
#  'Coordinating Activities - 2702',
#  'Coordinating Activities - 2716',
#  'Tamil Nadu - Coordinating Activities - 2753',
#  'Tamil Nadu - Coordinating Activities - 2754',
#  'Tamil Nadu - Coordinating Activities - 2759',
#  'Coordinating Activities - 2805',
#  'Coordinating Activities - 2818',
#  'Coordinating Activities - 2833',
#  'Coordinating Activities - 2858',
#  'Copywriter & Script Writer - 2504',
#  'Copywriter & Script Writer - 2543',
#  'Copywriter & Script Writer - 2546',
#  'Copywriter & Script Writer - 2663',
#  'Crafts Teacher - 2326',
#  'Linga Bhairavi - Crafts Teacher - 2640',
#  'Creative Director - 2381',
#  'Creative Director - 2814',
#  'Crop Husbandry - 2490',
#  'Customer Support Representatives - 2307',
#  'Customer Support Representatives - 2380',
#  'Customer Support Representatives - 2430',
#  'Customer Support Representatives - 2586',
#  'Customer Support Representatives - 2686',
#  'Customer Support Representatives - 2705',
#  'Customer Support Representatives - 2717',
#  'Marketing - Customer Support Representatives - 2721',
#  'Customer Support Representatives - 2835',
#  'Customer Support Representatives - 2851',
#  'Dance Teacher - 2647',
#  'Dance Teacher - 2770',
#  'Data Analyst - 2344',
#  'Data Analyst - 2443',
#  'Data Analyst - 2445',
#  'Data Analyst - 2464',
#  'Data Analyst - 2467',
#  'Data Analyst - 2492',
#  'Data Analyst - 2497',
#  'Data Analyst - 2501',
#  'Data Analyst - 2529',
#  'Data Analyst - 2688',
#  'Data Analyst - 2692',
#  'Data Analyst - 2712',
#  'Marketing - Data Analyst - 2729',
#  'Data Analyst - 2786',
#  'Infrastructure - Data Analyst - 2802',
#  'Data Analyst - 2804',
#  'Data Scientist - 2468',
#  'Data Scientist - 2711',
#  'Data Scientist - 2763',
#  'Data Scientist - 2781',
#  'Data Scientist - 2782',
#  'Data Scientist - 2839',
#  'Data Scientist - 2890',
#  'Dentist - 2448',
#  'Developer - 2518',
#  'Applications - Developer - 2610',
#  'Developer - 2783',
#  'Infrastructure - Developer - 2797',
#  'Developer - 2889',
#  'Applications - Devops Engineer - 2615',
#  'Infrastructure - Devops Engineer - 2799',
#  'Dining Support - 2253',
#  'Dining Support - 2384',
#  'Dining Support - 2720',
#  'Dining Support - 2734',
#  'Dining Support - 2855',
#  'Dubbing Artist - 2419',
#  'Marketing - E-Commerse - Category Manager - 2727',
#  'Editors with Animation skills - 2742',
#  'Electrical Design Engineer - 2308',
#  'Electrical Design Engineer - 2566',
#  'Electrical Design Engineer - 2848',
#  'Electrical Engineer - 2309',
#  'Electrical Maintenance Support - 2305',
#  'Electrical Maintenance Support - 2306',
#  'Electrical Maintenance Support - 2852',
#  'English Teacher - 2357',
#  'English Teacher - 2568',
#  'IHS - English Teacher - 2609',
#  'Applications - ERP Consultant - 2643',
#  'Farming support - 2343',
#  'Farming support - 2346',
#  'Farming support - 2433',
#  'Farming support - 2439',
#  'Farming support - 2649',
#  'Farming support - 2659',
#  'Farming support - 2761',
#  'Farming support - 2821',
#  'Farming support - 2823',
#  'Marketing - Fashion Designer - 2730',
#  'Finance & Accounting Executive - 2329',
#  'Finance & Accounting Executive - 2489',
#  'Finance & Accounting Executive - 2500',
#  'Finance & Accounting Executive - 2589',
#  'Finance & Accounting Executive - 2591',
#  'Finance & Accounting Executive - 2592',
#  'Finance & Accounting Executive - 2811',
#  'Finance & Accounting Executive - 2824',
#  'Fine Arts Teacher - 2619',
#  'French Translator - 2252',
#  'Front Office Activities - 2268',
#  'Front Office Activities - 2283',
#  'Front Office Activities - 2440',
#  'Front Office Activities - 2513',
#  'Front Office Activities - 2520',
#  'Linga Bhairavi - Front Office Activities - 2634',
#  'Front Office Activities - 2652',
#  'Front Office Activities - 2682',
#  'Front Office Activities - 2826',
#  'Front Office Activities - 2885',
#  'Front Office Activities - 2886',
#  'German Translator - 2258',
#  'Google Tag Manager / Google Analytics Specialist - 2466',
#  'Graphic Designer - 2297',
#  'Graphic Designer - 2362',
#  'Graphic Designer - 2406',
#  'Graphic Designer - 2505',
#  'Graphic Designer - 2538',
#  'Graphic Designer - 2664',
#  'Graphic Designer - 2693',
#  'Tamil Nadu - Graphic Designer - 2758',
#  'Growth Marketing Manager - 2548',
#  'Growth Marketing Manager - 2588',
#  'Growth Marketing Manager - 2883',
#  'Growth Strategist - 2673',
#  'Growth Strategist - 2872',
#  'Guest Care Support - 2294',
#  'Guest Care Support - 2347',
#  'Guest Care Support - 2348',
#  'Guest Care Support - 2349',
#  'Guest Care Support - 2352',
#  'Guest Care Support - 2451',
#  'Guiding Visitors - 2368',
#  'Guiding Visitors - 2369',
#  'Guiding Visitors - 2370',
#  'Guiding Visitors - 2373',
#  'Guiding Visitors - 2374',
#  'Guiding Visitors - 2376',
#  'Guiding Visitors - 2396',
#  'Tamil Nadu - Guiding Visitors - 2760',
#  'Guiding Visitors - 2817',
#  'Chennai & Kerala - Guiding Visitors - 2879',
#  'Gujarati Translator - 2425',
#  'Hindi Teacher - 2600',
#  'Hindi Translator - 2395',
#  'Hindi Translator - 2866',
#  'IHS - History teacher - 2603',
#  'History teacher - 2767',
#  'Hotel Management - 2718',
#  'Illustrator - 2407',
#  'LSP - Illustrator - 2463',
#  'Illustrator - 2597',
#  'Indonesian Translator - 2261',
#  'IT Hardware engineer - 2739',
#  'Infrastructure - IT Hardware engineer - 2801',
#  'Italian Translator - 2263',
#  'Japanese Translator - 2264',
#  'Kannada Translator - 2420',
#  'Korean Video Editor - 2265',
#  'Library Support - 2771',
#  'Library Support - 2834',
#  'Litigation Lawyer - 2789',
#  'Live Streaming Support - 2596',
#  'Live Streaming Support - 2666',
#  'Tamil Nadu - Live Streaming Support - 2751',
#  'Maintenance Activities - 2324',
#  'Maintenance Activities - 2706',
#  'Maintenance Activities - 2765',
#  'Maintenance Activities - 2819',
#  'Maintenance Activities - 2822',
#  'Maintenance Activities - 2829',
#  'Maintenance Support - 2262',
#  'Maintenance Support - 2277',
#  'Maintenance Support - 2332',
#  'Maintenance Support - 2394',
#  'Maintenance Support - 2398',
#  'Maintenance Support - 2595',
#  'Linga Bhairavi - Maintenance Support - 2632',
#  'Maintenance Support - 2812',
#  'Malayalam Translator - 2423',
#  'Mandarin Chinese Translator - 2270',
#  'Marathi Translator - 2424',
#  'Market Research - 2552',
#  'Market Research - 2641',
#  'Market Research - 2674',
#  'Market Research - 2708',
#  'Market Research - 2709',
#  'Marketing Manager/ Executive - 2289',
#  'Marketing Manager/ Executive - 2405',
#  'Marketing Manager/ Executive - 2516',
#  'Marketing Manager/ Executive - 2549',
#  'Marketing Manager/ Executive - 2587',
#  'Marketing Manager/ Executive - 2675',
#  'Marketing Manager/ Executive - 2696',
#  'Maths Teacher - 2477',
#  'LSP - Mechanical/Automobile Engineer - 2460',
#  'Media Coordinator - 2360',
#  'Media Coordinator - 2527',
#  'Media Operations - 2293',
#  'Media Operations - 2528',
#  'Medicine Room - 2401',
#  'Mixing Engineer - 2749',
#  'Music Producer / Arranger - 2748',
#  'Nepali Translator - 2428',
#  'Infrastructure - Network Engineer - 2773',
#  'Infrastructure - Network Engineer - 2774',
#  'Infrastructure - Network Engineer - 2775',
#  'Nurse - 2402',
#  'Nurse - 2436',
#  'TN - SPP & DP - Nursery Support - 2441',
#  'Nursery Support - 2862',
#  'Nutritionist - 2404',
#  'Odia Translator - 2427',
#  'On ground Support - 2291',
#  'On ground Support - 2333',
#  'On ground Support - 2383',
#  'On ground Support - 2449',
#  'On ground Support - 2485',
#  'On ground Support - 2517',
#  'On ground Support - 2521',
#  'Linga Bhairavi - On ground Support - 2638',
#  'Linga Bhairavi - On ground Support - 2639',
#  'On ground Support - 2653',
#  'On ground Support - 2701',
#  'On ground Support - 2795',
#  'On ground Support - 2842',
#  'On ground Support - 2857',
#  'On ground Support - 2873',
#  'On ground Support - 2893',
#  'Paid Ads Expert - 2470',
#  'Persian Translator - 2271',
#  'Pharmacist - 2437',
#  'Pharmacist - 2854',
#  'Photo/ Image Editing - 2415',
#  'Marketing - Photo/ Image Editing - 2724',
#  'Photographer - 2414',
#  'Marketing - Photographer - 2723',
#  'Physiotherapist - 2432',
#  'Piano Teacher - 2627',
#  'Platform Manager - 2475',
#  'Platform Manager - 2476',
#  'Platform Manager - 2478',
#  'Platform Manager - 2479',
#  'Platform Manager - 2481',
#  'Platform Manager - 2482',
#  'Platform Manager - 2483',
#  'Platform Manager - 2484',
#  'Platform Manager - 2486',
#  'Platform Manager - 2487',
#  'Platform Manager - 2522',
#  'Platform Manager - 2524',
#  'Platform Manager - 2531',
#  'Platform Manager - 2532',
#  'Platform Manager - 2533',
#  'Platform Manager - 2534',
#  'Platform Manager - 2535',
#  'Platform Manager - 2536',
#  'Platform Manager - 2537',
#  'Platform Manager - 2553',
#  'Platform Manager - 2554',
#  'Platform Manager - 2555',
#  'Platform Manager - 2556',
#  'Platform Manager - 2557',
#  'Platform Manager - 2558',
#  'Platform Manager - 2559',
#  'Platform Manager - 2560',
#  'Platform Manager - 2561',
#  'Platform Manager - 2562',
#  'Platform Manager - 2563',
#  'Platform Manager - 2564',
#  'Platform Manager - 2565',
#  'FPO Farmer Support - Platform Manager - 2676',
#  'Platform Manager - 2677',
#  'Polish Translator - 2272',
#  'Portuguese Translator - 2273',
#  'Pottery Wheel Teacher - 2618',
#  'Marketing - Pottery Wheel Teacher - 2880',
#  'Product Development - 2585',
#  'Marketing - Product Development - 2732',
#  'Applications - Product Manager - 2645',
#  'Product/ Mechanical Engineer - 2345',
#  'LSP - Product/ Mechanical Engineer - 2452',
#  'LSP - Product/ Mechanical Engineer - 2510',
#  'LSP - Product/Furniturer/Interior Designer - 2459',
#  'Project Manager - 2310',
#  'Project Manager - 2465',
#  'Project Manager - 2507',
#  'LSP - Project Manager - 2512',
#  'Project Manager - 2530',
#  'Project Manager - 2545',
#  'Project Manager - 2580',
#  'Project Manager - 2657',
#  'Project Manager - 2678',
#  'Project Manager - 2690',
#  'Tamil Nadu - Project Manager - 2756',
#  'Project Manager - 2784',
#  'Project Manager - 2792',
#  'Project Manager - 2809',
#  'Project Manager - 2871',
#  'Project Manager - 2876',
#  'Promotions - 2379',
#  'Promotions - 2519',
#  'Promotions - 2695',
#  'Promotions - 2700',
#  'Promotions - 2807',
#  'Promotions - 2847',
#  'Promotions - 2868',
#  'Public Relation Manager - 2412',
#  'Punjabi Translator - 2429',
#  'Recruitment Officer - 2255',
#  'Recruitment Officer - 2300',
#  'Recruitment Officer - 2658',
#  'Researcher - 2389',
#  'Researcher - 2410',
#  'Researcher - 2442',
#  'Researcher - 2498',
#  'Researcher - 2679',
#  'Linga Bhairavi - Rituals - 2633',
#  'Romanian Video Editor - 2274',
#  'Russian Video Editor - 2275',
#  'Safety Professionals - 2837',
#  'Sales Manager/ Executive - 2284',
#  'Sales Manager/ Executive - 2642',
#  'Sales Manager/ Executive - 2778',
#  'Sales Manager/ Executive - 2884',
#  'Sanskrit Teacher - 2598',
#  'Infrastructure - Server Engineer - 2776',
#  'Infrastructure - Server Engineer - 2777',
#  'Infrastructure - Server Engineer - 2798',
#  'Session Designer - 2660',
#  'Session Facilitator - 2662',
#  'Session Facilitator - 2860',
#  'Singers / Instrumentalists / Musicians - 2356',
#  'Singers / Instrumentalists / Musicians - 2624',
#  'Singers / Instrumentalists / Musicians - 2629',
#  'Singers / Instrumentalists / Musicians - 2750',
#  'Site Supervisor - 2256',
#  'Site Supervisor - 2350',
#  'LSP - Site Supervisor - 2461',
#  'Site Supervisor - 2861',
#  'Social media Manager - 2288',
#  'Social media Manager - 2431',
#  'Social media Manager - 2471',
#  'Social media Manager - 2480',
#  'Social media Manager - 2495',
#  'Social media Manager - 2523',
#  'Social media Manager - 2576',
#  'Social media Manager - 2577',
#  'Social media Manager - 2578',
#  'Social media Manager - 2667',
#  'Marketing - Social media Manager - 2728',
#  'Spanish Translator - 2279',
#  'Stay Area Support - 2719',
#  'Stay Area Support - 2830',
#  'LSP - Structural Engineer - 2456',
#  'Supervising Activities - 2267',
#  'Supervising Activities - 2301',
#  'Supervising Activities - 2302',
#  'Supervising Activities - 2779',
#  'Supervising Activities - 2780',
#  'Supervising Activities - 2849',
#  'Swimming coach - 2620',
#  'Tabla Teacher - 2628',
#  'Tamil Teacher - 2359',
#  'Tamil Teacher - 2599',
#  'IHS - Tamil Teacher - 2768',
#  'Tamil Translator - 2342',
#  'Teacher - Others - 2646',
#  'Teacher - Others - 2877',
#  'Teacher - Others - 2878',
#  'Applications - Technical Support - 2644',
#  'Technical support for Audio - 2313',
#  'Telugu Translator - 2421',
#  'Tennis coach - 2621',
#  'Test Engineer - 2354',
#  'Applications - Test Engineer - 2611',
#  'Test Engineer - 2704',
#  'Thai Translator - 2280',
#  'Traditional Chinese Video Editor - 2320',
#  'Transcription - 2457',
#  'Translators - 2251',
#  'Translators - 2259',
#  'Translators - 2260',
#  'Translators - 2278',
#  'Translators - 2319',
#  'Translators - 2321',
#  'Translators - 2387',
#  'Translators - 2867',
#  'UI Designer - 2408',
#  'UI Designer - 2581',
#  'Applications - UI Designer - 2762',
#  'UX Desinger - 2364',
#  'Veterinary Doctor - 2341',
#  'Video calls - Interviews - 2656',
#  'Video calls - Interviews - 2681',
#  'Video calls - Interviews - 2697',
#  'Video calls - Interviews - 2699',
#  'Video calls - Interviews - 2741',
#  'Video Editor - 2296',
#  'Video Editor - 2411',
#  'Video Editor - 2494',
#  'Video Editor - 2539',
#  'Video Editor - 2575',
#  'Video Editor - 2665',
#  'Tamil Nadu - Video Editor - 2757',
#  'Video Editor - 2815',
#  'Vietnamese Translator - 2322',
#  'Violin Teacher - 2626',
#  'Marketing - Visual Merchandiser - 2733',
#  'Visual Merchandiser - 2808',
#  'Access Control',
#  'Account Auditor',
#  'Accountant',
#  'Ad Creative Design Expert',
#  'Administrative Activities (Back Office)',
#  'Agri Marketing',
#  'Akshaya Volunteers',
#  'Allopathy Doctor',
#  'Arabic Translator',
#  'Architect',
#  'Art Teacher',
#  'Artificial Intelligence (AI) Enthusiast',
#  'Ashram Support',
#  'Ashram Tour Guide',
#  'Assamese Translator',
#  'Asset and Inventory management',
#  'Audio calls - Interviews',
#  'Bengali Translator',
#  'Biology Teacher',
#  'Business Analyst (BA)',
#  'CAD Designer',
#  'Call Centre',
#  'Carnatic Music Teacher',
#  'Chartered Accountant',
#  'Chemical/ Paint Engineer',
#  'Civil Estimators',
#  'Class Teacher - Junior School',
#  'Class Teacher - Middle School',
#  'Company Secretary',
#  'Compliance Lawyer',
#  'Computer Teacher',
#  'Content Creator',
#  'Content Manager',
#  'Content Researcher',
#  'Content Researcher - Tamil',
#  'Content Strategist',
#  'Content Support',
#  'Content Support Executive (CSE)',
#  'Content Writer',
#  'Content Writer - Media',
#  'Contracts Lawyer',
#  'Conversion Rate Expert',
#  'Coordinating Activities',
#  'Copywriter & Script Writer',
#  'Crafts Teacher',
#  'Creative Director',
#  'Crop Husbandry',
#  'Customer Support Representatives',
#  'Dance Teacher',
#  'Data Analyst',
#  'Data Scientist',
#  'Dentist',
#  'Developer',
#  'Devops Engineer',
#  'Dining Support',
#  'Dubbing Artist',
#  'E-Commerse - Category Manager',
#  'Editors with Animation skills',
#  'Electrical Design Engineer',
#  'Electrical Engineer',
#  'Electrical Maintenance Support',
#  'English Teacher',
#  'ERP Consultant',
#  'Farming support',
#  'Fashion Designer',
#  'Finance & Accounting Executive',
#  'Fine Arts Teacher',
#  'French Translator',
#  'Front Office Activities',
#  'German Translator',
#  'Google Tag Manager / Google Analytics Specialist',
#  'Graphic Designer',
#  'Growth Marketing Manager',
#  'Growth Strategist',
#  'Guest Care Support',
#  'Guiding Visitors',
#  'Gujarati Translator',
#  'Hindi Teacher',
#  'Hindi Translator',
#  'History teacher',
#  'Hotel Management',
#  'Illustrator',
#  'Indonesian Translator',
#  'IT Hardware engineer',
#  'Italian Translator',
#  'Japanese Translator',
#  'Kannada Translator',
#  'Korean Video Editor',
#  'Library Support',
#  'Litigation Lawyer',
#  'Live Streaming Support',
#  'Maintenance Activities',
#  'Maintenance Support',
#  'Malayalam Translator',
#  'Mandarin Chinese Translator',
#  'Marathi Translator',
#  'Market Research',
#  'Marketing Manager/ Executive',
#  'Maths Teacher',
#  'Mechanical/Automobile Engineer',
#  'Media Coordinator',
#  'Media Operations',
#  'Medicine Room',
#  'Mixing Engineer',
#  'Music Producer / Arranger',
#  'Nepali Translator',
#  'Network Engineer',
#  'Nurse',
#  'Nursery Support',
#  'Nutritionist',
#  'Odia Translator',
#  'On ground Support',
#  'Paid Ads Expert',
#  'Persian Translator',
#  'Pharmacist',
#  'Photo/ Image Editing',
#  'Photographer',
#  'Physiotherapist',
#  'Piano Teacher',
#  'Platform Manager',
#  'Polish Translator',
#  'Portuguese Translator',
#  'Pottery Wheel Teacher',
#  'Product Development',
#  'Product Manager',
#  'Product/ Mechanical Engineer',
#  'Product/Furniturer/Interior Designer',
#  'Project Manager',
#  'Promotions',
#  'Public Relation Manager',
#  'Punjabi Translator',
#  'Recruitment Officer',
#  'Researcher',
#  'Rituals',
#  'Romanian Video Editor',
#  'Russian Video Editor',
#  'Safety Professionals',
#  'Sales Manager/ Executive',
#  'Sanskrit Teacher',
#  'Server Engineer',
#  'Session Designer',
#  'Session Facilitator',
#  'Singers / Instrumentalists / Musicians',
#  'Site Supervisor',
#  'Social media Manager',
#  'Spanish Translator',
#  'Stay Area Support',
#  'Structural Engineer',
#  'Supervising Activities',
#  'Swimming coach',
#  'Tabla Teacher',
#  'Tamil Teacher',
#  'Tamil Translator',
#  'Teacher - Others',
#  'Technical Support',
#  'Technical support for Audio',
#  'Telugu Translator',
#  'Tennis coach',
#  'Test Engineer',
#  'Thai Translator',
#  'Traditional Chinese Video Editor',
#  'Transcription',
#  'Translators',
#  'UI Designer',
#  'UX Desinger',
#  'Veterinary Doctor',
#  'Video calls - Interviews',
#  'Video Editor',
#  'Vietnamese Translator',
#  'Violin Teacher',
#  'Visual Merchandiser']
